# %%
pip install beautifulsoup4 requests pandas
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.11.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2023.7.22)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-4.11.2-py3-none-any.whl (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 15.5 MB/s eta 0:00:00
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /usr/local/lib/python3.10/dist-packages (from selenium) (2.0.4)
# Collecting trio~=0.17 (from selenium)
#   Downloading trio-0.22.2-py3-none-any.whl (400 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.2/400.2 kB 26.9 MB/s eta 0:00:00
# Collecting trio-websocket~=0.9 (from selenium)
#   Downloading trio_websocket-0.10.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.10/dist-packages (from selenium) (2023.7.22)
# Requirement already satisfied: attrs>=20.1.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (23.1.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (3.4)
# Collecting outcome (from trio~=0.17->selenium)
#   Downloading outcome-1.2.0-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.1.3)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Collecting h11<1,>=0.9.0 (from wsproto>=0.14->trio-websocket~=0.9->selenium)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.7 MB/s eta 0:00:00
# Installing collected packages: outcome, h11, wsproto, trio, trio-websocket, selenium
# Successfully installed h11-0.14.0 outcome-1.2.0 selenium-4.11.2 trio-0.22.2 trio-websocket-0.10.3 wsproto-1.2.0

# %%
# BeautifulSoup 안됨
from bs4 import BeautifulSoup
from urllib.request import urlopen

response = urlopen("https://www.aladin.co.kr/shop/wproduct.aspx?ItemId=318773745")
soup = BeautifulSoup(response, 'html.parser')

for anchor in soup.select("div"):
	print(anchor.get_text())
# Out:
# 닫기
#
#
#
#
#
#
# HOME국내도서
#
#
# 국내도서
#
# 건강/취미
# 경제경영
# 공무원 수험서
# 과학
# 달력/기타
# 대학교재
# 만화
# 사회과학
# 소설/시/희곡
# 수험서/자격증
#
#
# 어린이
# 에세이
# 여행
# 역사
# 예술/대중문화
# 외국어
# 요리/살림
# 유아
# 인문학
# 자기계발
#
#
# 잡지
# 장르소설
# 전집/중고전집
# 종교/역학
# 좋은부모
# 청소년
# 컴퓨터/모바일
# 초등학교참고서
# 중학교참고서
# 고등학교참고서
#
#
# 베스트셀러
# 새로나온책
# 재정가도서
# 이벤트
# 독자북펀드
#
#
#
#
#
#
#
#
# 외국도서
#
#
# 외국도서
#
# 영미도서
#
# ELT/어학/사전
# 가정/원예/인테리어
# 건강/스포츠
# 경제경영
# 공예/취미/수집
# 만화
# 소설/시/희곡
# 여행
# 역사
# 요리
# 인문/사회
# 종교/명상/점술
# 청소년
# 해외잡지
#
#
#
# 대학교재/전문서
#
# 건축/디자인
# 교육/자료
# 기술공학
# 법률
# 수험서
# 언어학
# 예술/대중문화
# 의학
# 자연과학
# 컴퓨터
#
#
#
# 기타 언어권
#
# 독일 도서
# 스페인 도서
# 중국 도서
#
#
#
# 어린이
#
# 그림책
# 동화책
# 리더스
# 영어학습
# 챕터북
# 코스북
#
#
#
# 일본도서
#
# 문학
# 애니메이션 굿즈
# 잡지
# 코믹
# 베스트셀러
# 새로나온책
# 특가도서
# 이벤트
# LEXILE 지수별원서 읽기
#
#
#
#
#
#
#
#
#
# eBook
#
#
# eBook
#
# 건강/취미
# 경제경영
# 과학
# 라이트노벨
# 로맨스
# 만화
# 사회과학
# 소설/시/희곡
# 어린이
#
#
# 에세이
# 여행
# 역사
# 예술/대중문화
# 외국어
# 요리/살림
# 인문학
# 자기계발
# 좋은부모
# 청소년
#
#
# 판타지/무협
# BL
# 오디오북
#
#
# 베스트셀러
# 새로나온eBook
# 대여eBook
# 연재eBook
#
#
#
#
#
#
#
#
# 알라딘굿즈
#
#
# 알라딘굿즈
#
# 가방.파우치
# 데스크용품
# 독서용품
# 디지털
# 리빙·키친
# 문구
# 생활용품
# 의류·잡화
#
#
# 노트
# 독서대
# 북마크
# 북커버
# 사무용품
# 조명
# 파우치
# 필기구
#
#
# 피너츠
# 어린왕자
# 우주
# 앨리스
# 빨강머리 앤
# 고양이
# 모비딕
#
#
# 베스트셀러
# 생활용품연구소
# 알라딘 문방구
# 굿즈한정할인
#
#
#
#
#
#
#
#
# 온라인중고
#
#
# 온라인중고
#
# 경제경영
# 만화
# 사회과학
# 소설/시/희곡
# 수험서/자격증
# 어린이
# 에세이
# 역사
# 예술/대중문화
#
#
# 외국어
# 요리/살림
# 유아
# 인문학
# 자기계발
# 종교/역학
# 좋은부모
# 청소년
# 컴퓨터/모바일
#
#
# 중고 국내도서
#
# 중고
#                                                 음반
#
#
# 중고
#                                                 DVD/블루레이
#
#
# 중고  외국도서
#
#
#
# 많이 판매된 중고
# 새로 등록된 상품
# 어제 베스트 중고
# 역대 베스트 중고
# 최종 땡처리
# 단골 판매자 보기
#
#
# 판매자매니저
# 알라딘에 중고팔기
# 판매가능여부 & 판매가격 확인하기
# 온라인중고FAQ
#
#
#
#
#
#
#
#
# 우주점중고매장
#
#
# 중고매장
#
# 서울
#
# 가로수길점
# 강남점
# 강서홈플러스점
# 건대점
# 노원역점
# 대학로점
# 목동점
# 서울대입구역점
# 수유점
# 신림점
# 신촌점
# 연신내점
# 영등포점
#
#
# 이수역점
# 잠실롯데월드타워점
# 잠실새내역점
# 종로점
# 천호점
# 합정점
#
#
#
# 경기
#
# 동탄2하나로마트점
# 동탄점
# 범계점
# 부천점
# 분당서현점
# 분당야탑점
# 산본점
# 수원시청역점
# 수원점
# 수지점
# 의정부홈플러스점
# 일산점
# 평택점
# 화정점
#
#
#
# 광역시 등
#
# 광주상무점
# 광주충장로점
# 김해점
# 대구동성로점
# 대구상인점
# 대전시청역점
# 대전은행점
# 동대구역점
# 마산합성점
# 부산경성대 부경대역점
# 부산덕천점
# 부산서면점
# 부산센텀점
#
#
#
#
# 울산점
# 인천계산점
# 인천구월점
# 인천송도점
# 인천청라점
# 전주점
# 창원상남점
# 천안신불당점
# 청주점
#
#
#
#
#
# 중고매장 FAQ
# 판매가이드
# 판매가능여부 & 판매가격 확인하기
#
#
#
#
#
# 커피
#
#
# 커피
#
# 원두
# 드립백
# 콜드브루
# 커피 도구
# 스템프 이벤트
#
#
# 매장 메뉴
# 커피 매장
#
#
#
#
#
#
#
#
# 음반
#
#
# 음반
#
# 가요
# 국악
# 월드뮤직
# 재즈
# 종교/명상/기타
# 클래식
# 팝
# J-POP
# LP
# OST
#
#
# 베스트셀러
# 예약음반
# 새로나온음악
# 이벤트
# 해외구매
#
#
#
#
#
#
#
# 블루레이
#
#
# 블루레이
#
# 블루레이
#
# 3D 블루레이
# 공포/스릴러
# 다큐멘터리
# 드라마/코미디
# 애니메이션
# 액션/SF
# 음악
#
#
#
# DVD
#
# 공포/스릴러
# 교양/다큐멘터리
# 드라마/코미디
# 박스세트
# 성인
# 애니메이션
# 액션/어드벤쳐
# 유아/아동
#
#
# 음악DVD
# 제작국가별
# 취미/스포츠
# S.F./판타지
# TV시리즈
# VCD
# VHS
#
#
#
# 베스트셀러
# 예약 블루레이
# 새로나온 블루레이
#
# 예약알림 신청
#
#
# 이벤트
#
#
# 초특가아울렛
#
#
# 단독특가
#
# 중고블루레이
#
#
#
#
#
#
#
#
# 북플 ·서재
#
#
# 북플
# 알라딘서재
# 나의서재
#
#
#
#
#
# 로그인회원가입마이페이지나의계정주문/배송조회보관함구매함나의서재고객센터장바구니(0)
#
#
#
#
#
#
#
#
#
#
#
# 국내도서
#
#
#
# 통합검색
# 국내도서
# 외국도서
# eBook
# 알라딘굿즈
# 온라인중고
# 중고매장
# 커피
# 음반
# 블루레이
#
# 서재검색
# 서재태그
# 마이리뷰
# 마이리스트
# 마이페이퍼
# 서재
#
#
#
#
#
#
# 검색
#
#
#
# 검색
# 상세검색
#
#
#
#
#
#
#
#
#
#
#
#
# 분야보기
#
#
#
#
#
# 국내도서
#
#
# 건강/취미
# 경제경영
# 공무원 수험서
# 과학
# 달력/기타
# 대학교재
# 만화
# 사회과학
# 소설/시/희곡
# 수험서/자격증
# 어린이
# 에세이
# 여행
# 역사
# 예술/대중문화
#
#
# 외국어
# 요리/살림
# 유아
# 인문학
# 자기계발
# 잡지
# 장르소설
# 전집/중고전집
# 종교/역학
# 좋은부모
# 청소년
# 컴퓨터/모바일
# 초등학교참고서
# 중학교참고서
# 고등학교참고서
#
#
#
#
# 알라딘 굿즈
#
#
# 가방.파우치
# 데스크용품
# 독서용품
# 디지털
#
#
# 문구
# 생활용품
# 의류.잡화
# 리빙.키친
#
#
#
#
#
# 외국도서
#
#
# 영미도서
# ELT/어학/사전
# 가정/원예/인테리어
# 건강/스포츠
# 경제경영
# 공예/취미/수집
# 만화
# 소설/시/희곡
# 여행
# 역사
# 요리
# 인문/사회
# 종교/명상/점술
# 청소년
# 해외잡지
# 일본도서
# 문학
# 애니메이션 굿즈
#
#
# 어린이
# 그림책
# 동화책
# 리더스
# 영어학습
# 챕터북
# 코스북
# 중국도서
# 소설
# 중국어 교재
# 기타 언어권
# 독일 도서
# 베트남 도서
# 스페인 도서
# 프랑스 도서
# 기타 도서
# 잡지
# 코믹
#
#
#
#
#
# eBook
#
#
# 경제경영
# 라이트노벨
# 로맨스
# 만화
# 사회과학
# 소설/시
# 어린이
# 에세이
# 역사
# 예술/대중문화
# 인문학
# 자기계발
# 종교/역학
# 청소년
# 판타지/무협
# BL
# 오디오북
#
#
#
#
#
# 온라인중고
#
#
# 중고매장
# 중고 국내도서
# 경제경영
# 만화
# 사회과학
# 소설/시/희곡
# 어린이
# 에세이
# 유아
# 인문학
# 중고 음반
# 가요
# 국악
# 월드뮤직
# 클래식
# 팝
# 중고 DVD/블루레이
# 중고 외국도서
#
#
#
#
#
# 음반
#
#
# 가요
# 국악
# 월드뮤직
# 재즈
# 종교/명상/기타
# 클래식
# 팝
# J-POP
# LP
# OST
#
#
#
#
# 블루레이
#
#
# 공포/스릴러
# 드라마/코미디
# 블루레이
# 애니메이션
# 액션/어드벤쳐
# 음악DVD
# S.F./판타지
# TV시리즈
#
#
#
#
#
#
#
#
#
#
#
# 추천마법사
#
#
# 마법사의 선택
# 신간알리미
# 서재이웃의선택
# 오늘 본 상품
#
#
#
# 베스트셀러
#
# 새로나온 책
#
#
# 새로나온책
# 새로나올책
#
#
#
#
# 이벤트
#
#
# 이벤트
# 굿즈 총집합
# 정가인하도서
# 작가와의 만남
#
#
#
#
# 추천도서
#
#
# 추천도서
# 출판사 랭킹
#
#
#
#
#
#         단한권 인쇄소 N
#
#
#
#
#         투비컨티뉴드
#
#
#
#
# 알라디너TV
#
# 이 책의 한 문장
#
#
# 이 책의 한 문장
# 카드리뷰
# 북트레일러
#
#
#
# 북펀드
#
#
#
#
#
# 닫기
# 닫기
#
#
# 닫기
#
#
#
#
# HOME국내도서
#
#
# 국내도서
#
# 건강/취미
# 경제경영
# 공무원 수험서
# 과학
# 달력/기타
# 대학교재
# 만화
# 사회과학
# 소설/시/희곡
# 수험서/자격증
#
#
# 어린이
# 에세이
# 여행
# 역사
# 예술/대중문화
# 외국어
# 요리/살림
# 유아
# 인문학
# 자기계발
#
#
# 잡지
# 장르소설
# 전집/중고전집
# 종교/역학
# 좋은부모
# 청소년
# 컴퓨터/모바일
# 초등학교참고서
# 중학교참고서
# 고등학교참고서
#
#
# 베스트셀러
# 새로나온책
# 재정가도서
# 이벤트
# 독자북펀드
#
#
#
#
#
#
#
#
# 외국도서
#
#
# 외국도서
#
# 영미도서
#
# ELT/어학/사전
# 가정/원예/인테리어
# 건강/스포츠
# 경제경영
# 공예/취미/수집
# 만화
# 소설/시/희곡
# 여행
# 역사
# 요리
# 인문/사회
# 종교/명상/점술
# 청소년
# 해외잡지
#
#
#
# 대학교재/전문서
#
# 건축/디자인
# 교육/자료
# 기술공학
# 법률
# 수험서
# 언어학
# 예술/대중문화
# 의학
# 자연과학
# 컴퓨터
#
#
#
# 기타 언어권
#
# 독일 도서
# 스페인 도서
# 중국 도서
#
#
#
# 어린이
#
# 그림책
# 동화책
# 리더스
# 영어학습
# 챕터북
# 코스북
#
#
#
# 일본도서
#
# 문학
# 애니메이션 굿즈
# 잡지
# 코믹
# 베스트셀러
# 새로나온책
# 특가도서
# 이벤트
# LEXILE 지수별원서 읽기
#
#
#
#
#
#
#
#
#
# eBook
#
#
# eBook
#
# 건강/취미
# 경제경영
# 과학
# 라이트노벨
# 로맨스
# 만화
# 사회과학
# 소설/시/희곡
# 어린이
#
#
# 에세이
# 여행
# 역사
# 예술/대중문화
# 외국어
# 요리/살림
# 인문학
# 자기계발
# 좋은부모
# 청소년
#
#
# 판타지/무협
# BL
# 오디오북
#
#
# 베스트셀러
# 새로나온eBook
# 대여eBook
# 연재eBook
#
#
#
#
#
#
#
#
# 알라딘굿즈
#
#
# 알라딘굿즈
#
# 가방.파우치
# 데스크용품
# 독서용품
# 디지털
# 리빙·키친
# 문구
# 생활용품
# 의류·잡화
#
#
# 노트
# 독서대
# 북마크
# 북커버
# 사무용품
# 조명
# 파우치
# 필기구
#
#
# 피너츠
# 어린왕자
# 우주
# 앨리스
# 빨강머리 앤
# 고양이
# 모비딕
#
#
# 베스트셀러
# 생활용품연구소
# 알라딘 문방구
# 굿즈한정할인
#
#
#
#
#
#
#
#
# 온라인중고
#
#
# 온라인중고
#
# 경제경영
# 만화
# 사회과학
# 소설/시/희곡
# 수험서/자격증
# 어린이
# 에세이
# 역사
# 예술/대중문화
#
#
# 외국어
# 요리/살림
# 유아
# 인문학
# 자기계발
# 종교/역학
# 좋은부모
# 청소년
# 컴퓨터/모바일
#
#
# 중고 국내도서
#
# 중고
#                                                 음반
#
#
# 중고
#                                                 DVD/블루레이
#
#
# 중고  외국도서
#
#
#
# 많이 판매된 중고
# 새로 등록된 상품
# 어제 베스트 중고
# 역대 베스트 중고
# 최종 땡처리
# 단골 판매자 보기
#
#
# 판매자매니저
# 알라딘에 중고팔기
# 판매가능여부 & 판매가격 확인하기
# 온라인중고FAQ
#
#
#
#
#
#
#
#
# 우주점중고매장
#
#
# 중고매장
#
# 서울
#
# 가로수길점
# 강남점
# 강서홈플러스점
# 건대점
# 노원역점
# 대학로점
# 목동점
# 서울대입구역점
# 수유점
# 신림점
# 신촌점
# 연신내점
# 영등포점
#
#
# 이수역점
# 잠실롯데월드타워점
# 잠실새내역점
# 종로점
# 천호점
# 합정점
#
#
#
# 경기
#
# 동탄2하나로마트점
# 동탄점
# 범계점
# 부천점
# 분당서현점
# 분당야탑점
# 산본점
# 수원시청역점
# 수원점
# 수지점
# 의정부홈플러스점
# 일산점
# 평택점
# 화정점
#
#
#
# 광역시 등
#
# 광주상무점
# 광주충장로점
# 김해점
# 대구동성로점
# 대구상인점
# 대전시청역점
# 대전은행점
# 동대구역점
# 마산합성점
# 부산경성대 부경대역점
# 부산덕천점
# 부산서면점
# 부산센텀점
#
#
#
#
# 울산점
# 인천계산점
# 인천구월점
# 인천송도점
# 인천청라점
# 전주점
# 창원상남점
# 천안신불당점
# 청주점
#
#
#
#
#
# 중고매장 FAQ
# 판매가이드
# 판매가능여부 & 판매가격 확인하기
#
#
#
#
#
# 커피
#
#
# 커피
#
# 원두
# 드립백
# 콜드브루
# 커피 도구
# 스템프 이벤트
#
#
# 매장 메뉴
# 커피 매장
#
#
#
#
#
#
#
#
# 음반
#
#
# 음반
#
# 가요
# 국악
# 월드뮤직
# 재즈
# 종교/명상/기타
# 클래식
# 팝
# J-POP
# LP
# OST
#
#
# 베스트셀러
# 예약음반
# 새로나온음악
# 이벤트
# 해외구매
#
#
#
#
#
#
#
# 블루레이
#
#
# 블루레이
#
# 블루레이
#
# 3D 블루레이
# 공포/스릴러
# 다큐멘터리
# 드라마/코미디
# 애니메이션
# 액션/SF
# 음악
#
#
#
# DVD
#
# 공포/스릴러
# 교양/다큐멘터리
# 드라마/코미디
# 박스세트
# 성인
# 애니메이션
# 액션/어드벤쳐
# 유아/아동
#
#
# 음악DVD
# 제작국가별
# 취미/스포츠
# S.F./판타지
# TV시리즈
# VCD
# VHS
#
#
#
# 베스트셀러
# 예약 블루레이
# 새로나온 블루레이
#
# 예약알림 신청
#
#
# 이벤트
#
#
# 초특가아울렛
#
#
# 단독특가
#
# 중고블루레이
#
#
#
#
#
#
#
#
# 북플 ·서재
#
#
# 북플
# 알라딘서재
# 나의서재
#
#
#
#
#
# 로그인회원가입마이페이지나의계정주문/배송조회보관함구매함나의서재고객센터장바구니(0)
#
#
#
#
#
#
#
#
#
#
#
# 국내도서
#
#
#
# 통합검색
# 국내도서
# 외국도서
# eBook
# 알라딘굿즈
# 온라인중고
# 중고매장
# 커피
# 음반
# 블루레이
#
# 서재검색
# 서재태그
# 마이리뷰
# 마이리스트
# 마이페이퍼
# 서재
#
#
#
#
#
#
# 검색
#
#
#
# 검색
# 상세검색
#
#
#
#
#
#
#
#
#
#
#
#
# 분야보기
#
#
#
#
#
# 국내도서
#
#
# 건강/취미
# 경제경영
# 공무원 수험서
# 과학
# 달력/기타
# 대학교재
# 만화
# 사회과학
# 소설/시/희곡
# 수험서/자격증
# 어린이
# 에세이
# 여행
# 역사
# 예술/대중문화
#
#
# 외국어
# 요리/살림
# 유아
# 인문학
# 자기계발
# 잡지
# 장르소설
# 전집/중고전집
# 종교/역학
# 좋은부모
# 청소년
# 컴퓨터/모바일
# 초등학교참고서
# 중학교참고서
# 고등학교참고서
#
#
#
#
# 알라딘 굿즈
#
#
# 가방.파우치
# 데스크용품
# 독서용품
# 디지털
#
#
# 문구
# 생활용품
# 의류.잡화
# 리빙.키친
#
#
#
#
#
# 외국도서
#
#
# 영미도서
# ELT/어학/사전
# 가정/원예/인테리어
# 건강/스포츠
# 경제경영
# 공예/취미/수집
# 만화
# 소설/시/희곡
# 여행
# 역사
# 요리
# 인문/사회
# 종교/명상/점술
# 청소년
# 해외잡지
# 일본도서
# 문학
# 애니메이션 굿즈
#
#
# 어린이
# 그림책
# 동화책
# 리더스
# 영어학습
# 챕터북
# 코스북
# 중국도서
# 소설
# 중국어 교재
# 기타 언어권
# 독일 도서
# 베트남 도서
# 스페인 도서
# 프랑스 도서
# 기타 도서
# 잡지
# 코믹
#
#
#
#
#
# eBook
#
#
# 경제경영
# 라이트노벨
# 로맨스
# 만화
# 사회과학
# 소설/시
# 어린이
# 에세이
# 역사
# 예술/대중문화
# 인문학
# 자기계발
# 종교/역학
# 청소년
# 판타지/무협
# BL
# 오디오북
#
#
#
#
#
# 온라인중고
#
#
# 중고매장
# 중고 국내도서
# 경제경영
# 만화
# 사회과학
# 소설/시/희곡
# 어린이
# 에세이
# 유아
# 인문학
# 중고 음반
# 가요
# 국악
# 월드뮤직
# 클래식
# 팝
# 중고 DVD/블루레이
# 중고 외국도서
#
#
#
#
#
# 음반
#
#
# 가요
# 국악
# 월드뮤직
# 재즈
# 종교/명상/기타
# 클래식
# 팝
# J-POP
# LP
# OST
#
#
#
#
# 블루레이
#
#
# 공포/스릴러
# 드라마/코미디
# 블루레이
# 애니메이션
# 액션/어드벤쳐
# 음악DVD
# S.F./판타지
# TV시리즈
#
#
#
#
#
#
#
#
#
#
#
# 추천마법사
#
#
# 마법사의 선택
# 신간알리미
# 서재이웃의선택
# 오늘 본 상품
#
#
#
# 베스트셀러
#
# 새로나온 책
#
#
# 새로나온책
# 새로나올책
#
#
#
#
# 이벤트
#
#
# 이벤트
# 굿즈 총집합
# 정가인하도서
# 작가와의 만남
#
#
#
#
# 추천도서
#
#
# 추천도서
# 출판사 랭킹
#
#
#
#
#
#         단한권 인쇄소 N
#
#
#
#
#         투비컨티뉴드
#
#
#
#
# 알라디너TV
#
# 이 책의 한 문장
#
#
# 이 책의 한 문장
# 카드리뷰
# 북트레일러
#
#
#
# 북펀드
#
#
#
#
#
#
#
# HOME국내도서
#
#
# 국내도서
#
# 건강/취미
# 경제경영
# 공무원 수험서
# 과학
# 달력/기타
# 대학교재
# 만화
# 사회과학
# 소설/시/희곡
# 수험서/자격증
#
#
# 어린이
# 에세이
# 여행
# 역사
# 예술/대중문화
# 외국어
# 요리/살림
# 유아
# 인문학
# 자기계발
#
#
# 잡지
# 장르소설
# 전집/중고전집
# 종교/역학
# 좋은부모
# 청소년
# 컴퓨터/모바일
# 초등학교참고서
# 중학교참고서
# 고등학교참고서
#
#
# 베스트셀러
# 새로나온책
# 재정가도서
# 이벤트
# 독자북펀드
#
#
#
#
#
#
#
#
# 외국도서
#
#
# 외국도서
#
# 영미도서
#
# ELT/어학/사전
# 가정/원예/인테리어
# 건강/스포츠
# 경제경영
# 공예/취미/수집
# 만화
# 소설/시/희곡
# 여행
# 역사
# 요리
# 인문/사회
# 종교/명상/점술
# 청소년
# 해외잡지
#
#
#
# 대학교재/전문서
#
# 건축/디자인
# 교육/자료
# 기술공학
# 법률
# 수험서
# 언어학
# 예술/대중문화
# 의학
# 자연과학
# 컴퓨터
#
#
#
# 기타 언어권
#
# 독일 도서
# 스페인 도서
# 중국 도서
#
#
#
# 어린이
#
# 그림책
# 동화책
# 리더스
# 영어학습
# 챕터북
# 코스북
#
#
#
# 일본도서
#
# 문학
# 애니메이션 굿즈
# 잡지
# 코믹
# 베스트셀러
# 새로나온책
# 특가도서
# 이벤트
# LEXILE 지수별원서 읽기
#
#
#
#
#
#
#
#
#
# eBook
#
#
# eBook
#
# 건강/취미
# 경제경영
# 과학
# 라이트노벨
# 로맨스
# 만화
# 사회과학
# 소설/시/희곡
# 어린이
#
#
# 에세이
# 여행
# 역사
# 예술/대중문화
# 외국어
# 요리/살림
# 인문학
# 자기계발
# 좋은부모
# 청소년
#
#
# 판타지/무협
# BL
# 오디오북
#
#
# 베스트셀러
# 새로나온eBook
# 대여eBook
# 연재eBook
#
#
#
#
#
#
#
#
# 알라딘굿즈
#
#
# 알라딘굿즈
#
# 가방.파우치
# 데스크용품
# 독서용품
# 디지털
# 리빙·키친
# 문구
# 생활용품
# 의류·잡화
#
#
# 노트
# 독서대
# 북마크
# 북커버
# 사무용품
# 조명
# 파우치
# 필기구
#
#
# 피너츠
# 어린왕자
# 우주
# 앨리스
# 빨강머리 앤
# 고양이
# 모비딕
#
#
# 베스트셀러
# 생활용품연구소
# 알라딘 문방구
# 굿즈한정할인
#
#
#
#
#
#
#
#
# 온라인중고
#
#
# 온라인중고
#
# 경제경영
# 만화
# 사회과학
# 소설/시/희곡
# 수험서/자격증
# 어린이
# 에세이
# 역사
# 예술/대중문화
#
#
# 외국어
# 요리/살림
# 유아
# 인문학
# 자기계발
# 종교/역학
# 좋은부모
# 청소년
# 컴퓨터/모바일
#
#
# 중고 국내도서
#
# 중고
#                                                 음반
#
#
# 중고
#                                                 DVD/블루레이
#
#
# 중고  외국도서
#
#
#
# 많이 판매된 중고
# 새로 등록된 상품
# 어제 베스트 중고
# 역대 베스트 중고
# 최종 땡처리
# 단골 판매자 보기
#
#
# 판매자매니저
# 알라딘에 중고팔기
# 판매가능여부 & 판매가격 확인하기
# 온라인중고FAQ
#
#
#
#
#
#
#
#
# 우주점중고매장
#
#
# 중고매장
#
# 서울
#
# 가로수길점
# 강남점
# 강서홈플러스점
# 건대점
# 노원역점
# 대학로점
# 목동점
# 서울대입구역점
# 수유점
# 신림점
# 신촌점
# 연신내점
# 영등포점
#
#
# 이수역점
# 잠실롯데월드타워점
# 잠실새내역점
# 종로점
# 천호점
# 합정점
#
#
#
# 경기
#
# 동탄2하나로마트점
# 동탄점
# 범계점
# 부천점
# 분당서현점
# 분당야탑점
# 산본점
# 수원시청역점
# 수원점
# 수지점
# 의정부홈플러스점
# 일산점
# 평택점
# 화정점
#
#
#
# 광역시 등
#
# 광주상무점
# 광주충장로점
# 김해점
# 대구동성로점
# 대구상인점
# 대전시청역점
# 대전은행점
# 동대구역점
# 마산합성점
# 부산경성대 부경대역점
# 부산덕천점
# 부산서면점
# 부산센텀점
#
#
#
#
# 울산점
# 인천계산점
# 인천구월점
# 인천송도점
# 인천청라점
# 전주점
# 창원상남점
# 천안신불당점
# 청주점
#
#
#
#
#
# 중고매장 FAQ
# 판매가이드
# 판매가능여부 & 판매가격 확인하기
#
#
#
#
#
# 커피
#
#
# 커피
#
# 원두
# 드립백
# 콜드브루
# 커피 도구
# 스템프 이벤트
#
#
# 매장 메뉴
# 커피 매장
#
#
#
#
#
#
#
#
# 음반
#
#
# 음반
#
# 가요
# 국악
# 월드뮤직
# 재즈
# 종교/명상/기타
# 클래식
# 팝
# J-POP
# LP
# OST
#
#
# 베스트셀러
# 예약음반
# 새로나온음악
# 이벤트
# 해외구매
#
#
#
#
#
#
#
# 블루레이
#
#
# 블루레이
#
# 블루레이
#
# 3D 블루레이
# 공포/스릴러
# 다큐멘터리
# 드라마/코미디
# 애니메이션
# 액션/SF
# 음악
#
#
#
# DVD
#
# 공포/스릴러
# 교양/다큐멘터리
# 드라마/코미디
# 박스세트
# 성인
# 애니메이션
# 액션/어드벤쳐
# 유아/아동
#
#
# 음악DVD
# 제작국가별
# 취미/스포츠
# S.F./판타지
# TV시리즈
# VCD
# VHS
#
#
#
# 베스트셀러
# 예약 블루레이
# 새로나온 블루레이
#
# 예약알림 신청
#
#
# 이벤트
#
#
# 초특가아울렛
#
#
# 단독특가
#
# 중고블루레이
#
#
#
#
#
#
#
#
# 북플 ·서재
#
#
# 북플
# 알라딘서재
# 나의서재
#
#
#
#
#
# 로그인회원가입마이페이지나의계정주문/배송조회보관함구매함나의서재고객센터장바구니(0)
#
#
#
#
#
# HOME국내도서
#
#
# 국내도서
#
# 건강/취미
# 경제경영
# 공무원 수험서
# 과학
# 달력/기타
# 대학교재
# 만화
# 사회과학
# 소설/시/희곡
# 수험서/자격증
#
#
# 어린이
# 에세이
# 여행
# 역사
# 예술/대중문화
# 외국어
# 요리/살림
# 유아
# 인문학
# 자기계발
#
#
# 잡지
# 장르소설
# 전집/중고전집
# 종교/역학
# 좋은부모
# 청소년
# 컴퓨터/모바일
# 초등학교참고서
# 중학교참고서
# 고등학교참고서
#
#
# 베스트셀러
# 새로나온책
# 재정가도서
# 이벤트
# 독자북펀드
#
#
#
#
#
#
#
#
# 외국도서
#
#
# 외국도서
#
# 영미도서
#
# ELT/어학/사전
# 가정/원예/인테리어
# 건강/스포츠
# 경제경영
# 공예/취미/수집
# 만화
# 소설/시/희곡
# 여행
# 역사
# 요리
# 인문/사회
# 종교/명상/점술
# 청소년
# 해외잡지
#
#
#
# 대학교재/전문서
#
# 건축/디자인
# 교육/자료
# 기술공학
# 법률
# 수험서
# 언어학
# 예술/대중문화
# 의학
# 자연과학
# 컴퓨터
#
#
#
# 기타 언어권
#
# 독일 도서
# 스페인 도서
# 중국 도서
#
#
#
# 어린이
#
# 그림책
# 동화책
# 리더스
# 영어학습
# 챕터북
# 코스북
#
#
#
# 일본도서
#
# 문학
# 애니메이션 굿즈
# 잡지
# 코믹
# 베스트셀러
# 새로나온책
# 특가도서
# 이벤트
# LEXILE 지수별원서 읽기
#
#
#
#
#
#
#
#
#
# eBook
#
#
# eBook
#
# 건강/취미
# 경제경영
# 과학
# 라이트노벨
# 로맨스
# 만화
# 사회과학
# 소설/시/희곡
# 어린이
#
#
# 에세이
# 여행
# 역사
# 예술/대중문화
# 외국어
# 요리/살림
# 인문학
# 자기계발
# 좋은부모
# 청소년
#
#
# 판타지/무협
# BL
# 오디오북
#
#
# 베스트셀러
# 새로나온eBook
# 대여eBook
# 연재eBook
#
#
#
#
#
#
#
#
# 알라딘굿즈
#
#
# 알라딘굿즈
#
# 가방.파우치
# 데스크용품
# 독서용품
# 디지털
# 리빙·키친
# 문구
# 생활용품
# 의류·잡화
#
#
# 노트
# 독서대
# 북마크
# 북커버
# 사무용품
# 조명
# 파우치
# 필기구
#
#
# 피너츠
# 어린왕자
# 우주
# 앨리스
# 빨강머리 앤
# 고양이
# 모비딕
#
#
# 베스트셀러
# 생활용품연구소
# 알라딘 문방구
# 굿즈한정할인
#
#
#
#
#
#
#
#
# 온라인중고
#
#
# 온라인중고
#
# 경제경영
# 만화
# 사회과학
# 소설/시/희곡
# 수험서/자격증
# 어린이
# 에세이
# 역사
# 예술/대중문화
#
#
# 외국어
# 요리/살림
# 유아
# 인문학
# 자기계발
# 종교/역학
# 좋은부모
# 청소년
# 컴퓨터/모바일
#
#
# 중고 국내도서
#
# 중고
#                                                 음반
#
#
# 중고
#                                                 DVD/블루레이
#
#
# 중고  외국도서
#
#
#
# 많이 판매된 중고
# 새로 등록된 상품
# 어제 베스트 중고
# 역대 베스트 중고
# 최종 땡처리
# 단골 판매자 보기
#
#
# 판매자매니저
# 알라딘에 중고팔기
# 판매가능여부 & 판매가격 확인하기
# 온라인중고FAQ
#
#
#
#
#
#
#
#
# 우주점중고매장
#
#
# 중고매장
#
# 서울
#
# 가로수길점
# 강남점
# 강서홈플러스점
# 건대점
# 노원역점
# 대학로점
# 목동점
# 서울대입구역점
# 수유점
# 신림점
# 신촌점
# 연신내점
# 영등포점
#
#
# 이수역점
# 잠실롯데월드타워점
# 잠실새내역점
# 종로점
# 천호점
# 합정점
#
#
#
# 경기
#
# 동탄2하나로마트점
# 동탄점
# 범계점
# 부천점
# 분당서현점
# 분당야탑점
# 산본점
# 수원시청역점
# 수원점
# 수지점
# 의정부홈플러스점
# 일산점
# 평택점
# 화정점
#
#
#
# 광역시 등
#
# 광주상무점
# 광주충장로점
# 김해점
# 대구동성로점
# 대구상인점
# 대전시청역점
# 대전은행점
# 동대구역점
# 마산합성점
# 부산경성대 부경대역점
# 부산덕천점
# 부산서면점
# 부산센텀점
#
#
#
#
# 울산점
# 인천계산점
# 인천구월점
# 인천송도점
# 인천청라점
# 전주점
# 창원상남점
# 천안신불당점
# 청주점
#
#
#
#
#
# 중고매장 FAQ
# 판매가이드
# 판매가능여부 & 판매가격 확인하기
#
#
#
#
#
# 커피
#
#
# 커피
#
# 원두
# 드립백
# 콜드브루
# 커피 도구
# 스템프 이벤트
#
#
# 매장 메뉴
# 커피 매장
#
#
#
#
#
#
#
#
# 음반
#
#
# 음반
#
# 가요
# 국악
# 월드뮤직
# 재즈
# 종교/명상/기타
# 클래식
# 팝
# J-POP
# LP
# OST
#
#
# 베스트셀러
# 예약음반
# 새로나온음악
# 이벤트
# 해외구매
#
#
#
#
#
#
#
# 블루레이
#
#
# 블루레이
#
# 블루레이
#
# 3D 블루레이
# 공포/스릴러
# 다큐멘터리
# 드라마/코미디
# 애니메이션
# 액션/SF
# 음악
#
#
#
# DVD
#
# 공포/스릴러
# 교양/다큐멘터리
# 드라마/코미디
# 박스세트
# 성인
# 애니메이션
# 액션/어드벤쳐
# 유아/아동
#
#
# 음악DVD
# 제작국가별
# 취미/스포츠
# S.F./판타지
# TV시리즈
# VCD
# VHS
#
#
#
# 베스트셀러
# 예약 블루레이
# 새로나온 블루레이
#
# 예약알림 신청
#
#
# 이벤트
#
#
# 초특가아울렛
#
#
# 단독특가
#
# 중고블루레이
#
#
#
#
#
#
#
#
# 북플 ·서재
#
#
# 북플
# 알라딘서재
# 나의서재
#
#
#
#
#
# 로그인회원가입마이페이지나의계정주문/배송조회보관함구매함나의서재고객센터장바구니(0)
#
#
#
#
# 국내도서
#
# 건강/취미
# 경제경영
# 공무원 수험서
# 과학
# 달력/기타
# 대학교재
# 만화
# 사회과학
# 소설/시/희곡
# 수험서/자격증
#
#
# 어린이
# 에세이
# 여행
# 역사
# 예술/대중문화
# 외국어
# 요리/살림
# 유아
# 인문학
# 자기계발
#
#
# 잡지
# 장르소설
# 전집/중고전집
# 종교/역학
# 좋은부모
# 청소년
# 컴퓨터/모바일
# 초등학교참고서
# 중학교참고서
# 고등학교참고서
#
#
# 베스트셀러
# 새로나온책
# 재정가도서
# 이벤트
# 독자북펀드
#
#
#
#
#
#
#
#
#
# 국내도서
#
# 건강/취미
# 경제경영
# 공무원 수험서
# 과학
# 달력/기타
# 대학교재
# 만화
# 사회과학
# 소설/시/희곡
# 수험서/자격증
#
#
# 어린이
# 에세이
# 여행
# 역사
# 예술/대중문화
# 외국어
# 요리/살림
# 유아
# 인문학
# 자기계발
#
#
# 잡지
# 장르소설
# 전집/중고전집
# 종교/역학
# 좋은부모
# 청소년
# 컴퓨터/모바일
# 초등학교참고서
# 중학교참고서
# 고등학교참고서
#
#
# 베스트셀러
# 새로나온책
# 재정가도서
# 이벤트
# 독자북펀드
#
#
#
#
#
#
#
#
#
#
#
#
# 외국도서
#
# 영미도서
#
# ELT/어학/사전
# 가정/원예/인테리어
# 건강/스포츠
# 경제경영
# 공예/취미/수집
# 만화
# 소설/시/희곡
# 여행
# 역사
# 요리
# 인문/사회
# 종교/명상/점술
# 청소년
# 해외잡지
#
#
#
# 대학교재/전문서
#
# 건축/디자인
# 교육/자료
# 기술공학
# 법률
# 수험서
# 언어학
# 예술/대중문화
# 의학
# 자연과학
# 컴퓨터
#
#
#
# 기타 언어권
#
# 독일 도서
# 스페인 도서
# 중국 도서
#
#
#
# 어린이
#
# 그림책
# 동화책
# 리더스
# 영어학습
# 챕터북
# 코스북
#
#
#
# 일본도서
#
# 문학
# 애니메이션 굿즈
# 잡지
# 코믹
# 베스트셀러
# 새로나온책
# 특가도서
# 이벤트
# LEXILE 지수별원서 읽기
#
#
#
#
#
#
#
#
#
#
# 외국도서
#
# 영미도서
#
# ELT/어학/사전
# 가정/원예/인테리어
# 건강/스포츠
# 경제경영
# 공예/취미/수집
# 만화
# 소설/시/희곡
# 여행
# 역사
# 요리
# 인문/사회
# 종교/명상/점술
# 청소년
# 해외잡지
#
#
#
# 대학교재/전문서
#
# 건축/디자인
# 교육/자료
# 기술공학
# 법률
# 수험서
# 언어학
# 예술/대중문화
# 의학
# 자연과학
# 컴퓨터
#
#
#
# 기타 언어권
#
# 독일 도서
# 스페인 도서
# 중국 도서
#
#
#
# 어린이
#
# 그림책
# 동화책
# 리더스
# 영어학습
# 챕터북
# 코스북
#
#
#
# 일본도서
#
# 문학
# 애니메이션 굿즈
# 잡지
# 코믹
# 베스트셀러
# 새로나온책
# 특가도서
# 이벤트
# LEXILE 지수별원서 읽기
#
#
#
#
# 영미도서
#
# ELT/어학/사전
# 가정/원예/인테리어
# 건강/스포츠
# 경제경영
# 공예/취미/수집
# 만화
# 소설/시/희곡
# 여행
# 역사
# 요리
# 인문/사회
# 종교/명상/점술
# 청소년
# 해외잡지
#
#
#
# 대학교재/전문서
#
# 건축/디자인
# 교육/자료
# 기술공학
# 법률
# 수험서
# 언어학
# 예술/대중문화
# 의학
# 자연과학
# 컴퓨터
#
#
#
# 기타 언어권
#
# 독일 도서
# 스페인 도서
# 중국 도서
#
#
#
# 어린이
#
# 그림책
# 동화책
# 리더스
# 영어학습
# 챕터북
# 코스북
#
#
#
# 일본도서
#
# 문학
# 애니메이션 굿즈
# 잡지
# 코믹
# 베스트셀러
# 새로나온책
# 특가도서
# 이벤트
# LEXILE 지수별원서 읽기
#
#
#
#
#
#
#
#
#
#
#
#
# eBook
#
# 건강/취미
# 경제경영
# 과학
# 라이트노벨
# 로맨스
# 만화
# 사회과학
# 소설/시/희곡
# 어린이
#
#
# 에세이
# 여행
# 역사
# 예술/대중문화
# 외국어
# 요리/살림
# 인문학
# 자기계발
# 좋은부모
# 청소년
#
#
# 판타지/무협
# BL
# 오디오북
#
#
# 베스트셀러
# 새로나온eBook
# 대여eBook
# 연재eBook
#
#
#
#
#
#
#
#
#
# eBook
#
# 건강/취미
# 경제경영
# 과학
# 라이트노벨
# 로맨스
# 만화
# 사회과학
# 소설/시/희곡
# 어린이
#
#
# 에세이
# 여행
# 역사
# 예술/대중문화
# 외국어
# 요리/살림
# 인문학
# 자기계발
# 좋은부모
# 청소년
#
#
# 판타지/무협
# BL
# 오디오북
#
#
# 베스트셀러
# 새로나온eBook
# 대여eBook
# 연재eBook
#
#
#
#
#
#
#
#
#
#
#
#
# 알라딘굿즈
#
# 가방.파우치
# 데스크용품
# 독서용품
# 디지털
# 리빙·키친
# 문구
# 생활용품
# 의류·잡화
#
#
# 노트
# 독서대
# 북마크
# 북커버
# 사무용품
# 조명
# 파우치
# 필기구
#
#
# 피너츠
# 어린왕자
# 우주
# 앨리스
# 빨강머리 앤
# 고양이
# 모비딕
#
#
# 베스트셀러
# 생활용품연구소
# 알라딘 문방구
# 굿즈한정할인
#
#
#
#
#
#
#
#
#
# 알라딘굿즈
#
# 가방.파우치
# 데스크용품
# 독서용품
# 디지털
# 리빙·키친
# 문구
# 생활용품
# 의류·잡화
#
#
# 노트
# 독서대
# 북마크
# 북커버
# 사무용품
# 조명
# 파우치
# 필기구
#
#
# 피너츠
# 어린왕자
# 우주
# 앨리스
# 빨강머리 앤
# 고양이
# 모비딕
#
#
# 베스트셀러
# 생활용품연구소
# 알라딘 문방구
# 굿즈한정할인
#
#
#
#
#
#
#
#
#
#
#
#
# 온라인중고
#
# 경제경영
# 만화
# 사회과학
# 소설/시/희곡
# 수험서/자격증
# 어린이
# 에세이
# 역사
# 예술/대중문화
#
#
# 외국어
# 요리/살림
# 유아
# 인문학
# 자기계발
# 종교/역학
# 좋은부모
# 청소년
# 컴퓨터/모바일
#
#
# 중고 국내도서
#
# 중고
#                                                 음반
#
#
# 중고
#                                                 DVD/블루레이
#
#
# 중고  외국도서
#
#
#
# 많이 판매된 중고
# 새로 등록된 상품
# 어제 베스트 중고
# 역대 베스트 중고
# 최종 땡처리
# 단골 판매자 보기
#
#
# 판매자매니저
# 알라딘에 중고팔기
# 판매가능여부 & 판매가격 확인하기
# 온라인중고FAQ
#
#
#
#
#
#
#
#
#
#
# 온라인중고
#
# 경제경영
# 만화
# 사회과학
# 소설/시/희곡
# 수험서/자격증
# 어린이
# 에세이
# 역사
# 예술/대중문화
#
#
# 외국어
# 요리/살림
# 유아
# 인문학
# 자기계발
# 종교/역학
# 좋은부모
# 청소년
# 컴퓨터/모바일
#
#
# 중고 국내도서
#
# 중고
#                                                 음반
#
#
# 중고
#                                                 DVD/블루레이
#
#
# 중고  외국도서
#
#
#
# 많이 판매된 중고
# 새로 등록된 상품
# 어제 베스트 중고
# 역대 베스트 중고
# 최종 땡처리
# 단골 판매자 보기
#
#
# 판매자매니저
# 알라딘에 중고팔기
# 판매가능여부 & 판매가격 확인하기
# 온라인중고FAQ
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 중고매장
#
# 서울
#
# 가로수길점
# 강남점
# 강서홈플러스점
# 건대점
# 노원역점
# 대학로점
# 목동점
# 서울대입구역점
# 수유점
# 신림점
# 신촌점
# 연신내점
# 영등포점
#
#
# 이수역점
# 잠실롯데월드타워점
# 잠실새내역점
# 종로점
# 천호점
# 합정점
#
#
#
# 경기
#
# 동탄2하나로마트점
# 동탄점
# 범계점
# 부천점
# 분당서현점
# 분당야탑점
# 산본점
# 수원시청역점
# 수원점
# 수지점
# 의정부홈플러스점
# 일산점
# 평택점
# 화정점
#
#
#
# 광역시 등
#
# 광주상무점
# 광주충장로점
# 김해점
# 대구동성로점
# 대구상인점
# 대전시청역점
# 대전은행점
# 동대구역점
# 마산합성점
# 부산경성대 부경대역점
# 부산덕천점
# 부산서면점
# 부산센텀점
#
#
#
#
# 울산점
# 인천계산점
# 인천구월점
# 인천송도점
# 인천청라점
# 전주점
# 창원상남점
# 천안신불당점
# 청주점
#
#
#
#
#
# 중고매장 FAQ
# 판매가이드
# 판매가능여부 & 판매가격 확인하기
#
#
#
#
#
#
#
# 중고매장
#
# 서울
#
# 가로수길점
# 강남점
# 강서홈플러스점
# 건대점
# 노원역점
# 대학로점
# 목동점
# 서울대입구역점
# 수유점
# 신림점
# 신촌점
# 연신내점
# 영등포점
#
#
# 이수역점
# 잠실롯데월드타워점
# 잠실새내역점
# 종로점
# 천호점
# 합정점
#
#
#
# 경기
#
# 동탄2하나로마트점
# 동탄점
# 범계점
# 부천점
# 분당서현점
# 분당야탑점
# 산본점
# 수원시청역점
# 수원점
# 수지점
# 의정부홈플러스점
# 일산점
# 평택점
# 화정점
#
#
#
# 광역시 등
#
# 광주상무점
# 광주충장로점
# 김해점
# 대구동성로점
# 대구상인점
# 대전시청역점
# 대전은행점
# 동대구역점
# 마산합성점
# 부산경성대 부경대역점
# 부산덕천점
# 부산서면점
# 부산센텀점
#
#
#
#
# 울산점
# 인천계산점
# 인천구월점
# 인천송도점
# 인천청라점
# 전주점
# 창원상남점
# 천안신불당점
# 청주점
#
#
#
#
# 서울
#
# 가로수길점
# 강남점
# 강서홈플러스점
# 건대점
# 노원역점
# 대학로점
# 목동점
# 서울대입구역점
# 수유점
# 신림점
# 신촌점
# 연신내점
# 영등포점
#
#
# 이수역점
# 잠실롯데월드타워점
# 잠실새내역점
# 종로점
# 천호점
# 합정점
#
#
#
# 경기
#
# 동탄2하나로마트점
# 동탄점
# 범계점
# 부천점
# 분당서현점
# 분당야탑점
# 산본점
# 수원시청역점
# 수원점
# 수지점
# 의정부홈플러스점
# 일산점
# 평택점
# 화정점
#
#
#
# 광역시 등
#
# 광주상무점
# 광주충장로점
# 김해점
# 대구동성로점
# 대구상인점
# 대전시청역점
# 대전은행점
# 동대구역점
# 마산합성점
# 부산경성대 부경대역점
# 부산덕천점
# 부산서면점
# 부산센텀점
#
#
#
#
# 울산점
# 인천계산점
# 인천구월점
# 인천송도점
# 인천청라점
# 전주점
# 창원상남점
# 천안신불당점
# 청주점
#
#
#
#
# 중고매장 FAQ
# 판매가이드
# 판매가능여부 & 판매가격 확인하기
#
#
#
#
#
#
#
#
#
#
# 커피
#
# 원두
# 드립백
# 콜드브루
# 커피 도구
# 스템프 이벤트
#
#
# 매장 메뉴
# 커피 매장
#
#
#
#
#
#
#
#
#
# 커피
#
# 원두
# 드립백
# 콜드브루
# 커피 도구
# 스템프 이벤트
#
#
# 매장 메뉴
# 커피 매장
#
#
#
#
#
#
#
#
#
#
#
#
# 음반
#
# 가요
# 국악
# 월드뮤직
# 재즈
# 종교/명상/기타
# 클래식
# 팝
# J-POP
# LP
# OST
#
#
# 베스트셀러
# 예약음반
# 새로나온음악
# 이벤트
# 해외구매
#
#
#
#
#
#
#
#
#
# 음반
#
# 가요
# 국악
# 월드뮤직
# 재즈
# 종교/명상/기타
# 클래식
# 팝
# J-POP
# LP
# OST
#
#
# 베스트셀러
# 예약음반
# 새로나온음악
# 이벤트
# 해외구매
#
#
#
#
#
#
#
#
#
#
#
#
# 블루레이
#
# 블루레이
#
# 3D 블루레이
# 공포/스릴러
# 다큐멘터리
# 드라마/코미디
# 애니메이션
# 액션/SF
# 음악
#
#
#
# DVD
#
# 공포/스릴러
# 교양/다큐멘터리
# 드라마/코미디
# 박스세트
# 성인
# 애니메이션
# 액션/어드벤쳐
# 유아/아동
#
#
# 음악DVD
# 제작국가별
# 취미/스포츠
# S.F./판타지
# TV시리즈
# VCD
# VHS
#
#
#
# 베스트셀러
# 예약 블루레이
# 새로나온 블루레이
#
# 예약알림 신청
#
#
# 이벤트
#
#
# 초특가아울렛
#
#
# 단독특가
#
# 중고블루레이
#
#
#
#
#
#
#
#
#
# 블루레이
#
# 블루레이
#
# 3D 블루레이
# 공포/스릴러
# 다큐멘터리
# 드라마/코미디
# 애니메이션
# 액션/SF
# 음악
#
#
#
# DVD
#
# 공포/스릴러
# 교양/다큐멘터리
# 드라마/코미디
# 박스세트
# 성인
# 애니메이션
# 액션/어드벤쳐
# 유아/아동
#
#
# 음악DVD
# 제작국가별
# 취미/스포츠
# S.F./판타지
# TV시리즈
# VCD
# VHS
#
#
#
# 베스트셀러
# 예약 블루레이
# 새로나온 블루레이
#
# 예약알림 신청
#
#
# 이벤트
#
#
# 초특가아울렛
#
#
# 단독특가
#
# 중고블루레이
#
#
#
# 블루레이
#
# 3D 블루레이
# 공포/스릴러
# 다큐멘터리
# 드라마/코미디
# 애니메이션
# 액션/SF
# 음악
#
#
#
# DVD
#
# 공포/스릴러
# 교양/다큐멘터리
# 드라마/코미디
# 박스세트
# 성인
# 애니메이션
# 액션/어드벤쳐
# 유아/아동
#
#
# 음악DVD
# 제작국가별
# 취미/스포츠
# S.F./판타지
# TV시리즈
# VCD
# VHS
#
#
#
#
#
#
#
#
#
#
#
#
# 북플
# 알라딘서재
# 나의서재
#
#
# 나의계정주문/배송조회보관함구매함나의서재
#
#
#
#
#
#
#
#
#
#
#
# 국내도서
#
#
#
# 통합검색
# 국내도서
# 외국도서
# eBook
# 알라딘굿즈
# 온라인중고
# 중고매장
# 커피
# 음반
# 블루레이
#
# 서재검색
# 서재태그
# 마이리뷰
# 마이리스트
# 마이페이퍼
# 서재
#
#
#
#
#
#
# 검색
#
#
#
# 검색
# 상세검색
#
#
#
#
#
#
#
#
#
#
#
#
# 국내도서
#
#
#
# 통합검색
# 국내도서
# 외국도서
# eBook
# 알라딘굿즈
# 온라인중고
# 중고매장
# 커피
# 음반
# 블루레이
#
# 서재검색
# 서재태그
# 마이리뷰
# 마이리스트
# 마이페이퍼
# 서재
#
#
#
#
#
#
# 검색
#
#
#
# 검색
# 상세검색
#
#
#
#
#
# 국내도서
#
#
#
# 통합검색
# 국내도서
# 외국도서
# eBook
# 알라딘굿즈
# 온라인중고
# 중고매장
# 커피
# 음반
# 블루레이
#
# 서재검색
# 서재태그
# 마이리뷰
# 마이리스트
# 마이페이퍼
# 서재
#
#
#
#
#
#
# 검색
#
#
#
# 검색
# 상세검색
#
#
#
#
# 통합검색
# 국내도서
# 외국도서
# eBook
# 알라딘굿즈
# 온라인중고
# 중고매장
# 커피
# 음반
# 블루레이
#
# 서재검색
# 서재태그
# 마이리뷰
# 마이리스트
# 마이페이퍼
# 서재
#
#
#
#
#
# 통합검색
# 국내도서
# 외국도서
# eBook
# 알라딘굿즈
# 온라인중고
# 중고매장
# 커피
# 음반
# 블루레이
#
# 서재검색
# 서재태그
# 마이리뷰
# 마이리스트
# 마이페이퍼
# 서재
#
#
#
#
#
# 검색
#
#
#
#
#
#
#
#
#
# 분야보기
#
#
#
#
#
# 국내도서
#
#
# 건강/취미
# 경제경영
# 공무원 수험서
# 과학
# 달력/기타
# 대학교재
# 만화
# 사회과학
# 소설/시/희곡
# 수험서/자격증
# 어린이
# 에세이
# 여행
# 역사
# 예술/대중문화
#
#
# 외국어
# 요리/살림
# 유아
# 인문학
# 자기계발
# 잡지
# 장르소설
# 전집/중고전집
# 종교/역학
# 좋은부모
# 청소년
# 컴퓨터/모바일
# 초등학교참고서
# 중학교참고서
# 고등학교참고서
#
#
#
#
# 알라딘 굿즈
#
#
# 가방.파우치
# 데스크용품
# 독서용품
# 디지털
#
#
# 문구
# 생활용품
# 의류.잡화
# 리빙.키친
#
#
#
#
#
# 외국도서
#
#
# 영미도서
# ELT/어학/사전
# 가정/원예/인테리어
# 건강/스포츠
# 경제경영
# 공예/취미/수집
# 만화
# 소설/시/희곡
# 여행
# 역사
# 요리
# 인문/사회
# 종교/명상/점술
# 청소년
# 해외잡지
# 일본도서
# 문학
# 애니메이션 굿즈
#
#
# 어린이
# 그림책
# 동화책
# 리더스
# 영어학습
# 챕터북
# 코스북
# 중국도서
# 소설
# 중국어 교재
# 기타 언어권
# 독일 도서
# 베트남 도서
# 스페인 도서
# 프랑스 도서
# 기타 도서
# 잡지
# 코믹
#
#
#
#
#
# eBook
#
#
# 경제경영
# 라이트노벨
# 로맨스
# 만화
# 사회과학
# 소설/시
# 어린이
# 에세이
# 역사
# 예술/대중문화
# 인문학
# 자기계발
# 종교/역학
# 청소년
# 판타지/무협
# BL
# 오디오북
#
#
#
#
#
# 온라인중고
#
#
# 중고매장
# 중고 국내도서
# 경제경영
# 만화
# 사회과학
# 소설/시/희곡
# 어린이
# 에세이
# 유아
# 인문학
# 중고 음반
# 가요
# 국악
# 월드뮤직
# 클래식
# 팝
# 중고 DVD/블루레이
# 중고 외국도서
#
#
#
#
#
# 음반
#
#
# 가요
# 국악
# 월드뮤직
# 재즈
# 종교/명상/기타
# 클래식
# 팝
# J-POP
# LP
# OST
#
#
#
#
# 블루레이
#
#
# 공포/스릴러
# 드라마/코미디
# 블루레이
# 애니메이션
# 액션/어드벤쳐
# 음악DVD
# S.F./판타지
# TV시리즈
#
#
#
#
#
#
#
#
#
#
#
# 추천마법사
#
#
# 마법사의 선택
# 신간알리미
# 서재이웃의선택
# 오늘 본 상품
#
#
#
# 베스트셀러
#
# 새로나온 책
#
#
# 새로나온책
# 새로나올책
#
#
#
#
# 이벤트
#
#
# 이벤트
# 굿즈 총집합
# 정가인하도서
# 작가와의 만남
#
#
#
#
# 추천도서
#
#
# 추천도서
# 출판사 랭킹
#
#
#
#
#
#         단한권 인쇄소 N
#
#
#
#
#         투비컨티뉴드
#
#
#
#
# 알라디너TV
#
# 이 책의 한 문장
#
#
# 이 책의 한 문장
# 카드리뷰
# 북트레일러
#
#
#
# 북펀드
#
#
#
#
#
#
#
# 국내도서
#
#
# 건강/취미
# 경제경영
# 공무원 수험서
# 과학
# 달력/기타
# 대학교재
# 만화
# 사회과학
# 소설/시/희곡
# 수험서/자격증
# 어린이
# 에세이
# 여행
# 역사
# 예술/대중문화
#
#
# 외국어
# 요리/살림
# 유아
# 인문학
# 자기계발
# 잡지
# 장르소설
# 전집/중고전집
# 종교/역학
# 좋은부모
# 청소년
# 컴퓨터/모바일
# 초등학교참고서
# 중학교참고서
# 고등학교참고서
#
#
#
#
# 알라딘 굿즈
#
#
# 가방.파우치
# 데스크용품
# 독서용품
# 디지털
#
#
# 문구
# 생활용품
# 의류.잡화
# 리빙.키친
#
#
#
#
#
# 외국도서
#
#
# 영미도서
# ELT/어학/사전
# 가정/원예/인테리어
# 건강/스포츠
# 경제경영
# 공예/취미/수집
# 만화
# 소설/시/희곡
# 여행
# 역사
# 요리
# 인문/사회
# 종교/명상/점술
# 청소년
# 해외잡지
# 일본도서
# 문학
# 애니메이션 굿즈
#
#
# 어린이
# 그림책
# 동화책
# 리더스
# 영어학습
# 챕터북
# 코스북
# 중국도서
# 소설
# 중국어 교재
# 기타 언어권
# 독일 도서
# 베트남 도서
# 스페인 도서
# 프랑스 도서
# 기타 도서
# 잡지
# 코믹
#
#
#
#
#
# eBook
#
#
# 경제경영
# 라이트노벨
# 로맨스
# 만화
# 사회과학
# 소설/시
# 어린이
# 에세이
# 역사
# 예술/대중문화
# 인문학
# 자기계발
# 종교/역학
# 청소년
# 판타지/무협
# BL
# 오디오북
#
#
#
#
#
# 온라인중고
#
#
# 중고매장
# 중고 국내도서
# 경제경영
# 만화
# 사회과학
# 소설/시/희곡
# 어린이
# 에세이
# 유아
# 인문학
# 중고 음반
# 가요
# 국악
# 월드뮤직
# 클래식
# 팝
# 중고 DVD/블루레이
# 중고 외국도서
#
#
#
#
#
# 음반
#
#
# 가요
# 국악
# 월드뮤직
# 재즈
# 종교/명상/기타
# 클래식
# 팝
# J-POP
# LP
# OST
#
#
#
#
# 블루레이
#
#
# 공포/스릴러
# 드라마/코미디
# 블루레이
# 애니메이션
# 액션/어드벤쳐
# 음악DVD
# S.F./판타지
# TV시리즈
#
#
#
#
#
#
#
#
#
# 국내도서
#
#
# 건강/취미
# 경제경영
# 공무원 수험서
# 과학
# 달력/기타
# 대학교재
# 만화
# 사회과학
# 소설/시/희곡
# 수험서/자격증
# 어린이
# 에세이
# 여행
# 역사
# 예술/대중문화
#
#
# 외국어
# 요리/살림
# 유아
# 인문학
# 자기계발
# 잡지
# 장르소설
# 전집/중고전집
# 종교/역학
# 좋은부모
# 청소년
# 컴퓨터/모바일
# 초등학교참고서
# 중학교참고서
# 고등학교참고서
#
#
#
# 알라딘 굿즈
#
#
# 가방.파우치
# 데스크용품
# 독서용품
# 디지털
#
#
# 문구
# 생활용품
# 의류.잡화
# 리빙.키친
#
#
# 외국도서
#
#
# 영미도서
# ELT/어학/사전
# 가정/원예/인테리어
# 건강/스포츠
# 경제경영
# 공예/취미/수집
# 만화
# 소설/시/희곡
# 여행
# 역사
# 요리
# 인문/사회
# 종교/명상/점술
# 청소년
# 해외잡지
# 일본도서
# 문학
# 애니메이션 굿즈
#
#
# 어린이
# 그림책
# 동화책
# 리더스
# 영어학습
# 챕터북
# 코스북
# 중국도서
# 소설
# 중국어 교재
# 기타 언어권
# 독일 도서
# 베트남 도서
# 스페인 도서
# 프랑스 도서
# 기타 도서
# 잡지
# 코믹
#
#
# eBook
#
#
# 경제경영
# 라이트노벨
# 로맨스
# 만화
# 사회과학
# 소설/시
# 어린이
# 에세이
# 역사
# 예술/대중문화
# 인문학
# 자기계발
# 종교/역학
# 청소년
# 판타지/무협
# BL
# 오디오북
#
#
# 온라인중고
#
#
# 중고매장
# 중고 국내도서
# 경제경영
# 만화
# 사회과학
# 소설/시/희곡
# 어린이
# 에세이
# 유아
# 인문학
# 중고 음반
# 가요
# 국악
# 월드뮤직
# 클래식
# 팝
# 중고 DVD/블루레이
# 중고 외국도서
#
#
# 음반
#
#
# 가요
# 국악
# 월드뮤직
# 재즈
# 종교/명상/기타
# 클래식
# 팝
# J-POP
# LP
# OST
#
#
#
# 블루레이
#
#
# 공포/스릴러
# 드라마/코미디
# 블루레이
# 애니메이션
# 액션/어드벤쳐
# 음악DVD
# S.F./판타지
# TV시리즈
#
#
#
#
#
#
#
# 마법사의 선택
# 신간알리미
# 서재이웃의선택
# 오늘 본 상품
#
#
#
#
# 새로나온책
# 새로나올책
#
#
#
#
# 이벤트
# 굿즈 총집합
# 정가인하도서
# 작가와의 만남
#
#
#
#
# 추천도서
# 출판사 랭킹
#
#
#
#
# 이 책의 한 문장
# 카드리뷰
# 북트레일러
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  이 책을 읽고 싶은 사람
#
#
#
#
#
# 모든 회원 (0)
# 친구 (0)
#
#
#
#
# 도서
# 분야
# 저자
# 시리즈
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 무료배송소득공제
#
#
# 문과 남자의 과학 공부 - 나는 무엇이고 왜 존재하며 어디로 가는가?
#
#
# 유시민 (지은이)돌베개2023-06-23
#
#
#
#
#
#
#
#
#
#
#
#  공유하기
#
#
#
#
# 페이스북
# 트위터
# SMS 문자
# 이메일
# 프린트
# 상품 정보복사
#
#
#
#
#
# URL 복사
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 이전다음마지막 이미지입니다.
#
#
#
#
#
#
#
#
#
#
#
#
#  미리보기
#
#
#
#
#
#
#
#
#
#
# 여름의 과학 + 책모양 거울(대상도서 포함 국내서 2만원 이상)
#
# 정가17,500원 판매가15,750원 (10%, 1,750원 할인) 마일리지870원(5%)  + 멤버십(3~1%)+ 5만원이상 구매시 2,000원
#
#
# 배송료무료311
# 양탄자배송지금 주문하면 내일 밤 11시 잠들기전 배송(중구 서소문로 89-31 기준)  지역변경
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 검색어(도로명,건물명,지번)를 입력해주세요(지번+도로명 통합 검색)
#
#
#
#
#
# 검색
#
#
#
#
#
#
#
#
# 종합 주간 7위,   종합 1위 3주|Sales Point : 288,115  세일즈 포인트 SalesPoint는 판매량과 판매기간에 근거하여 해당 상품의 판매도를 산출한 알라딘만의 판매지수법입니다.최근 판매분에 가중치를 준 판매점수. 팔릴수록 올라가고 덜 팔리면 내려갑니다. 그래서 최근 베스트셀러는 높은 점수이며, 꾸준히 팔리는 스테디셀러들도 어느 정도 포인트를 유지합니다. `SalesPoint`는 매일매일 업데이트됩니다. + more 9.2 100자평(123)리뷰(19)이 책 어때요?
# 전자책11,250원
#
#
#
#
#  카드/간편결제 할인 무이자 할부 소득공제 710원
#
#
#
#
#  무이자 할부 안내
#
#
#
#
#
#                 * 2~3개월 무이자 : 신한, 국민,현대,롯데,하나,삼성
# * 2~4개월 무이자 : 농협
# * 2~6개월 무이자 : 비씨, 우리
# ※ 제휴 신용카드 결제시 무이자+제휴카드 혜택 가능합니다.
# ※ 오프라인결제/Non ActiveX 결제(간편결제)/카카오페이/네이버페이/페이코 등 간편결제/법인/체크/선불/기프트/문화누리/은행계열카드/ 알라딘 캐시와 같은 정기과금 결제 등은 행사대상에서 제외됩니다.
# ※ 무이자할부 결제 시 카드사 포인트 적립에서 제외될 수 있습니다.
# ※ 본 행사는 카드사 사정에 따라 변경 또는 중단될 수 있습니다.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 문과 남자의 과학 공부 - 나는 무엇이고 왜 존재하며 어디로 가는가?
#
# 15,750원 (10%, 1,750원 할인)
#
#
#
#
#
#
#
#
#
#
# 바로구매장바구니 담기
#
#
#
#
#
#
#     수량
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  상품을 장바구니에 담았습니다.
#
#
#
# 장바구니 가기
#
#
#
#
#
#
#
# x 닫기
#
# 상품을 장바구니에 담았습니다.
# 주문과정의 배송옵션에서 '영풍문고Now드림 방문 픽업' 을 선택해주세요.
#
# 장바구니 가기
#
#
#
#
#
#
#
#
#
#
# 지금 바로 선물하기
#
# 장바구니 담기
#
# 장바구니에 담으면다른 상품과 함께 선물할 수 있어요.
#
#
#
#
#
#  품절도서센터 장바구니에 담았습니다.
#
#
# 결제 후 신청이 완료됩니다.
#
#
# 품절도서 센터 장바구니
#
#
#
#
#
#  보관함에 상품 담기
#
#
#
#
#
#
#
#
#
#
#
# 장바구니 담기바로구매
#
#  선물하기  안내
#
#
# 배송 주소를 몰라도 선물할 수 있어요.
#
#
# 선물받으실 분의 핸드폰번호, 이메일 주소, 카카오톡 , 서재 주소 중 하나를 입력하시면 선물이 전송됩니다. + more
#
#
#
#
#
# 무엇을 선물할지 망설여진다면 알라딘 상품권을 선물해보세요.+ more
#
#
#
#
#
#
# 선물하기보관함 +보관함마이리스트
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  중고 등록알림 신청
#
#  중고로 팔기
#
#
#
#
# 알라딘에 팔기
#
#
# 회원에게 팔기
#
#
#
#
#
#
#
#
#
#
#
#  1:1 문의하기
#
#
# 분류 요청하기
# 품절/절판
# 출고 예상시간
# 가격 정보
# 상품상세정보
# 오탈자 신고
# 리뷰 신고
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 기본정보
# 기본정보
#
#
# 304쪽135*210mm395gISBN : 9791192836188
#
#
#
# 주제 분류
# 신간알리미 신청
#
#
#
# 국내도서 > 인문학 > 교양 인문학 접기국내도서 > 과학 > 기초과학/교양과학 접기국내도서 > 인문학 > 인문 에세이 접기
#
#
#
#
#
#
#
#
#
#
#
#
#  무지를 드러내며 겸허하게 새로운 배움을 시작하는 태도, 새로운 앎을 받아들이는 과정, 배움을 통해 변하게 된 마음과 관점까지, 독자들이 자극받을 지점이 많은 책이다. 올여름휴가의 책으로 한자리는 이미 선점된 듯하다. - 인문 MD 김경영 (2023.06.23)
#
# 출판사 제공 북트레일러출판사 제공 북트레일러
#
#
#
#
#
#
#
#
#
#
#
#
#
# 이벤트
# 이벤트
#
#
#
#
#    <문과 남자의 과학 공부> 포함 국내도서 2만원 이상 구매 시, 유시민 사인 키보드 덮개     여름의 과학 + 책모양 거울(대상도서 포함 국내도서 2만원 이상 구매 시)     <문과 남자의 과학 공부> 구매 시, 오디오 매거진     이벤트 대상도서 1권이상 구매시 책꽂이 37호     이벤트 대상도서 포함 청소년 분야 2만원 이상 구매 시 단어장     책모양 유리문진(대상도서 포함 국내서 2만원 이상)     화제의 책+알라딘 굿즈 (이벤트 도서 포함, 국내도서 4만원 이상)     8월 특별 선물. 캠핑 의자 · 충전 패드 (이벤트 도서 포함, 국내서.외서 5만원 이상)
#      책과 함께 무료배송 - 함께 사기 좋은 특가 도서 · 저가 도서 총집합
#      이 달의 적립금 혜택     모든 책 오늘 출고 서비스 오픈     함께 사면 무료배송. 1천원~4천원대  굿즈 총집합     이 시간, 알라딘 사은품 총집합!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  이 책을 읽고 싶은 사람
#
#
#
#
#
# 모든 회원 (0)
# 친구 (0)
#
#
#
#
# 도서
# 분야
# 저자
# 시리즈
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  이 책을 읽고 싶은 사람
#
#
#
#
#
# 모든 회원 (0)
# 친구 (0)
#
#
#
#
# 도서
# 분야
# 저자
# 시리즈
#
#
#
#
#
#
#
#
#
#
#
# 모든 회원 (0)
# 친구 (0)
#
#
#
#
# 도서
# 분야
# 저자
# 시리즈
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 무료배송소득공제
#
#
# 문과 남자의 과학 공부 - 나는 무엇이고 왜 존재하며 어디로 가는가?
#
#
# 유시민 (지은이)돌베개2023-06-23
#
#
#
#
#
#
#
#
#
#
#
#  공유하기
#
#
#
#
# 페이스북
# 트위터
# SMS 문자
# 이메일
# 프린트
# 상품 정보복사
#
#
#
#
#
# URL 복사
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 무료배송소득공제
#
#
# 문과 남자의 과학 공부 - 나는 무엇이고 왜 존재하며 어디로 가는가?
#
#
# 유시민 (지은이)돌베개2023-06-23
#
#
#
#
#
#
#
#
#
#
#
#  공유하기
#
#
#
#
# 페이스북
# 트위터
# SMS 문자
# 이메일
# 프린트
# 상품 정보복사
#
#
#
#
#
# URL 복사
#
#
#
#
#
#
#
#
#
# 무료배송소득공제
#
#
# 문과 남자의 과학 공부 - 나는 무엇이고 왜 존재하며 어디로 가는가?
#
#
# 유시민 (지은이)돌베개2023-06-23
#
#
#
#
#
#
# 무료배송소득공제
#
#
# 문과 남자의 과학 공부 - 나는 무엇이고 왜 존재하며 어디로 가는가?
#
#
# 유시민 (지은이)돌베개2023-06-23
#
#
# 문과 남자의 과학 공부 - 나는 무엇이고 왜 존재하며 어디로 가는가?
#
#
#
#
#
#  공유하기
#
#
#
#
# 페이스북
# 트위터
# SMS 문자
# 이메일
# 프린트
# 상품 정보복사
#
#
#
#
#
# URL 복사
#
#
#
#
#  공유하기
#
#
#
#
# 페이스북
# 트위터
# SMS 문자
# 이메일
# 프린트
# 상품 정보복사
#
#
#
#
#
# URL 복사
#
#
#
#
#
#
# 페이스북
# 트위터
# SMS 문자
# 이메일
# 프린트
# 상품 정보복사
#
#
#
#
#
# URL 복사
#
#
# URL 복사
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 이전다음마지막 이미지입니다.
#
#
#
#
#
#
#
#
#
#
#
#
#  미리보기
#
#
#
#
#
#
#
#
#
#
# 여름의 과학 + 책모양 거울(대상도서 포함 국내서 2만원 이상)
#
# 정가17,500원 판매가15,750원 (10%, 1,750원 할인) 마일리지870원(5%)  + 멤버십(3~1%)+ 5만원이상 구매시 2,000원
#
#
# 배송료무료311
# 양탄자배송지금 주문하면 내일 밤 11시 잠들기전 배송(중구 서소문로 89-31 기준)  지역변경
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 검색어(도로명,건물명,지번)를 입력해주세요(지번+도로명 통합 검색)
#
#
#
#
#
# 검색
#
#
#
#
#
#
#
#
# 종합 주간 7위,   종합 1위 3주|Sales Point : 288,115  세일즈 포인트 SalesPoint는 판매량과 판매기간에 근거하여 해당 상품의 판매도를 산출한 알라딘만의 판매지수법입니다.최근 판매분에 가중치를 준 판매점수. 팔릴수록 올라가고 덜 팔리면 내려갑니다. 그래서 최근 베스트셀러는 높은 점수이며, 꾸준히 팔리는 스테디셀러들도 어느 정도 포인트를 유지합니다. `SalesPoint`는 매일매일 업데이트됩니다. + more 9.2 100자평(123)리뷰(19)이 책 어때요?
# 전자책11,250원
#
#
#
#
#  카드/간편결제 할인 무이자 할부 소득공제 710원
#
#
#
#
#  무이자 할부 안내
#
#
#
#
#
#                 * 2~3개월 무이자 : 신한, 국민,현대,롯데,하나,삼성
# * 2~4개월 무이자 : 농협
# * 2~6개월 무이자 : 비씨, 우리
# ※ 제휴 신용카드 결제시 무이자+제휴카드 혜택 가능합니다.
# ※ 오프라인결제/Non ActiveX 결제(간편결제)/카카오페이/네이버페이/페이코 등 간편결제/법인/체크/선불/기프트/문화누리/은행계열카드/ 알라딘 캐시와 같은 정기과금 결제 등은 행사대상에서 제외됩니다.
# ※ 무이자할부 결제 시 카드사 포인트 적립에서 제외될 수 있습니다.
# ※ 본 행사는 카드사 사정에 따라 변경 또는 중단될 수 있습니다.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 문과 남자의 과학 공부 - 나는 무엇이고 왜 존재하며 어디로 가는가?
#
# 15,750원 (10%, 1,750원 할인)
#
#
#
#
#
#
#
#
#
#
# 바로구매장바구니 담기
#
#
#
#
#
#
#     수량
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  상품을 장바구니에 담았습니다.
#
#
#
# 장바구니 가기
#
#
#
#
#
#
#
# x 닫기
#
# 상품을 장바구니에 담았습니다.
# 주문과정의 배송옵션에서 '영풍문고Now드림 방문 픽업' 을 선택해주세요.
#
# 장바구니 가기
#
#
#
#
#
#
#
#
#
#
# 지금 바로 선물하기
#
# 장바구니 담기
#
# 장바구니에 담으면다른 상품과 함께 선물할 수 있어요.
#
#
#
#
#
#  품절도서센터 장바구니에 담았습니다.
#
#
# 결제 후 신청이 완료됩니다.
#
#
# 품절도서 센터 장바구니
#
#
#
#
#
#  보관함에 상품 담기
#
#
#
#
#
#
#
#
#
#
#
# 장바구니 담기바로구매
#
#  선물하기  안내
#
#
# 배송 주소를 몰라도 선물할 수 있어요.
#
#
# 선물받으실 분의 핸드폰번호, 이메일 주소, 카카오톡 , 서재 주소 중 하나를 입력하시면 선물이 전송됩니다. + more
#
#
#
#
#
# 무엇을 선물할지 망설여진다면 알라딘 상품권을 선물해보세요.+ more
#
#
#
#
#
#
# 선물하기보관함 +보관함마이리스트
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  중고 등록알림 신청
#
#  중고로 팔기
#
#
#
#
# 알라딘에 팔기
#
#
# 회원에게 팔기
#
#
#
#
#
#
#
#
#
#
#
#  1:1 문의하기
#
#
# 분류 요청하기
# 품절/절판
# 출고 예상시간
# 가격 정보
# 상품상세정보
# 오탈자 신고
# 리뷰 신고
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 이전다음마지막 이미지입니다.
#
#
#
#
#
#
#
#
#
#
#
#
#  미리보기
#
#
#
#
#
#
#
#
# 이전다음마지막 이미지입니다.
#
#
#
#
#
#
#
#
# 이전
# 다음
#
#
# 마지막 이미지입니다.
# 마지막 이미지입니다.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 마지막 이미지입니다.
# 마지막 이미지입니다.
#
#
#  미리보기
#
#
#
#
#
# 여름의 과학 + 책모양 거울(대상도서 포함 국내서 2만원 이상)
#
# 정가17,500원 판매가15,750원 (10%, 1,750원 할인) 마일리지870원(5%)  + 멤버십(3~1%)+ 5만원이상 구매시 2,000원
#
#
# 배송료무료311
# 양탄자배송지금 주문하면 내일 밤 11시 잠들기전 배송(중구 서소문로 89-31 기준)  지역변경
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 검색어(도로명,건물명,지번)를 입력해주세요(지번+도로명 통합 검색)
#
#
#
#
#
# 검색
#
#
#
#
#
#
#
#
# 종합 주간 7위,   종합 1위 3주|Sales Point : 288,115  세일즈 포인트 SalesPoint는 판매량과 판매기간에 근거하여 해당 상품의 판매도를 산출한 알라딘만의 판매지수법입니다.최근 판매분에 가중치를 준 판매점수. 팔릴수록 올라가고 덜 팔리면 내려갑니다. 그래서 최근 베스트셀러는 높은 점수이며, 꾸준히 팔리는 스테디셀러들도 어느 정도 포인트를 유지합니다. `SalesPoint`는 매일매일 업데이트됩니다. + more 9.2 100자평(123)리뷰(19)이 책 어때요?
# 전자책11,250원
#
#
#
#
#  카드/간편결제 할인 무이자 할부 소득공제 710원
#
#
#
#
#  무이자 할부 안내
#
#
#
#
#
#                 * 2~3개월 무이자 : 신한, 국민,현대,롯데,하나,삼성
# * 2~4개월 무이자 : 농협
# * 2~6개월 무이자 : 비씨, 우리
# ※ 제휴 신용카드 결제시 무이자+제휴카드 혜택 가능합니다.
# ※ 오프라인결제/Non ActiveX 결제(간편결제)/카카오페이/네이버페이/페이코 등 간편결제/법인/체크/선불/기프트/문화누리/은행계열카드/ 알라딘 캐시와 같은 정기과금 결제 등은 행사대상에서 제외됩니다.
# ※ 무이자할부 결제 시 카드사 포인트 적립에서 제외될 수 있습니다.
# ※ 본 행사는 카드사 사정에 따라 변경 또는 중단될 수 있습니다.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 문과 남자의 과학 공부 - 나는 무엇이고 왜 존재하며 어디로 가는가?
#
# 15,750원 (10%, 1,750원 할인)
#
#
#
#
#
#
#
#
#
#
# 바로구매장바구니 담기
#
#
#
#
#
#
#     수량
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  상품을 장바구니에 담았습니다.
#
#
#
# 장바구니 가기
#
#
#
#
#
#
#
# x 닫기
#
# 상품을 장바구니에 담았습니다.
# 주문과정의 배송옵션에서 '영풍문고Now드림 방문 픽업' 을 선택해주세요.
#
# 장바구니 가기
#
#
#
#
#
#
#
#
#
#
# 지금 바로 선물하기
#
# 장바구니 담기
#
# 장바구니에 담으면다른 상품과 함께 선물할 수 있어요.
#
#
#
#
#
#  품절도서센터 장바구니에 담았습니다.
#
#
# 결제 후 신청이 완료됩니다.
#
#
# 품절도서 센터 장바구니
#
#
#
#
#
#  보관함에 상품 담기
#
#
#
#
#
#
#
#
#
#
#
# 장바구니 담기바로구매
#
#  선물하기  안내
#
#
# 배송 주소를 몰라도 선물할 수 있어요.
#
#
# 선물받으실 분의 핸드폰번호, 이메일 주소, 카카오톡 , 서재 주소 중 하나를 입력하시면 선물이 전송됩니다. + more
#
#
#
#
#
# 무엇을 선물할지 망설여진다면 알라딘 상품권을 선물해보세요.+ more
#
#
#
#
#
#
# 선물하기보관함 +보관함마이리스트
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  중고 등록알림 신청
#
#  중고로 팔기
#
#
#
#
# 알라딘에 팔기
#
#
# 회원에게 팔기
#
#
#
#
#
#
#
#
#
#
#
#  1:1 문의하기
#
#
# 분류 요청하기
# 품절/절판
# 출고 예상시간
# 가격 정보
# 상품상세정보
# 오탈자 신고
# 리뷰 신고
#
#
#
#
#
#
#
#
#
#
#
#
# 여름의 과학 + 책모양 거울(대상도서 포함 국내서 2만원 이상)
#
# 정가17,500원 판매가15,750원 (10%, 1,750원 할인) 마일리지870원(5%)  + 멤버십(3~1%)+ 5만원이상 구매시 2,000원
#
#
# 배송료무료311
# 양탄자배송지금 주문하면 내일 밤 11시 잠들기전 배송(중구 서소문로 89-31 기준)  지역변경
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 검색어(도로명,건물명,지번)를 입력해주세요(지번+도로명 통합 검색)
#
#
#
#
#
# 검색
#
#
#
#
#
#
#
#
# 종합 주간 7위,   종합 1위 3주|Sales Point : 288,115  세일즈 포인트 SalesPoint는 판매량과 판매기간에 근거하여 해당 상품의 판매도를 산출한 알라딘만의 판매지수법입니다.최근 판매분에 가중치를 준 판매점수. 팔릴수록 올라가고 덜 팔리면 내려갑니다. 그래서 최근 베스트셀러는 높은 점수이며, 꾸준히 팔리는 스테디셀러들도 어느 정도 포인트를 유지합니다. `SalesPoint`는 매일매일 업데이트됩니다. + more 9.2 100자평(123)리뷰(19)이 책 어때요?
# 전자책11,250원
#
#
#
#
#  카드/간편결제 할인 무이자 할부 소득공제 710원
#
#
#
#
#  무이자 할부 안내
#
#
#
#
#
#                 * 2~3개월 무이자 : 신한, 국민,현대,롯데,하나,삼성
# * 2~4개월 무이자 : 농협
# * 2~6개월 무이자 : 비씨, 우리
# ※ 제휴 신용카드 결제시 무이자+제휴카드 혜택 가능합니다.
# ※ 오프라인결제/Non ActiveX 결제(간편결제)/카카오페이/네이버페이/페이코 등 간편결제/법인/체크/선불/기프트/문화누리/은행계열카드/ 알라딘 캐시와 같은 정기과금 결제 등은 행사대상에서 제외됩니다.
# ※ 무이자할부 결제 시 카드사 포인트 적립에서 제외될 수 있습니다.
# ※ 본 행사는 카드사 사정에 따라 변경 또는 중단될 수 있습니다.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 문과 남자의 과학 공부 - 나는 무엇이고 왜 존재하며 어디로 가는가?
#
# 15,750원 (10%, 1,750원 할인)
#
#
#
#
#
#
#
#
#
#
# 바로구매장바구니 담기
#
#
#
#
#
#
#     수량
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  상품을 장바구니에 담았습니다.
#
#
#
# 장바구니 가기
#
#
#
#
#
#
#
# x 닫기
#
# 상품을 장바구니에 담았습니다.
# 주문과정의 배송옵션에서 '영풍문고Now드림 방문 픽업' 을 선택해주세요.
#
# 장바구니 가기
#
#
#
#
#
#
#
#
#
#
# 지금 바로 선물하기
#
# 장바구니 담기
#
# 장바구니에 담으면다른 상품과 함께 선물할 수 있어요.
#
#
#
#
#
#  품절도서센터 장바구니에 담았습니다.
#
#
# 결제 후 신청이 완료됩니다.
#
#
# 품절도서 센터 장바구니
#
#
#
#
#
#  보관함에 상품 담기
#
#
#
#
#
#
#
#
#
#
#
# 장바구니 담기바로구매
#
#  선물하기  안내
#
#
# 배송 주소를 몰라도 선물할 수 있어요.
#
#
# 선물받으실 분의 핸드폰번호, 이메일 주소, 카카오톡 , 서재 주소 중 하나를 입력하시면 선물이 전송됩니다. + more
#
#
#
#
#
# 무엇을 선물할지 망설여진다면 알라딘 상품권을 선물해보세요.+ more
#
#
#
#
#
#
# 선물하기보관함 +보관함마이리스트
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  중고 등록알림 신청
#
#  중고로 팔기
#
#
#
#
# 알라딘에 팔기
#
#
# 회원에게 팔기
#
#
#
#
#
#
#
#
#
#
#
#  1:1 문의하기
#
#
# 분류 요청하기
# 품절/절판
# 출고 예상시간
# 가격 정보
# 상품상세정보
# 오탈자 신고
# 리뷰 신고
#
#
#
#
#
#
#
#
#
# 여름의 과학 + 책모양 거울(대상도서 포함 국내서 2만원 이상)
#
# 정가17,500원 판매가15,750원 (10%, 1,750원 할인)
# 정가
# 17,500원
# 판매가
# 15,750원 (10%, 1,750원 할인)
# 마일리지870원(5%)  + 멤버십(3~1%)+ 5만원이상 구매시 2,000원
# 마일리지
# 870원(5%)  + 멤버십(3~1%)
# + 5만원이상 구매시 2,000원
#
# 배송료무료
# 배송료
# 무료
# 311
# 양탄자배송지금 주문하면 내일 밤 11시 잠들기전 배송(중구 서소문로 89-31 기준)  지역변경
# 311
#
# 311
# 양탄자배송지금 주문하면 내일 밤 11시 잠들기전 배송
# (중구 서소문로 89-31 기준)  지역변경
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 검색어(도로명,건물명,지번)를 입력해주세요(지번+도로명 통합 검색)
#
#
#
#
#
# 검색
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 검색어(도로명,건물명,지번)를 입력해주세요(지번+도로명 통합 검색)
#
#
#
#
#
# 검색
#
#
#
#
#
# 검색어(도로명,건물명,지번)를 입력해주세요(지번+도로명 통합 검색)
#
#
#
#
#
# 검색
#
# 검색
#
#
#
# 종합 주간 7위,   종합 1위 3주|Sales Point : 288,115  세일즈 포인트 SalesPoint는 판매량과 판매기간에 근거하여 해당 상품의 판매도를 산출한 알라딘만의 판매지수법입니다.최근 판매분에 가중치를 준 판매점수. 팔릴수록 올라가고 덜 팔리면 내려갑니다. 그래서 최근 베스트셀러는 높은 점수이며, 꾸준히 팔리는 스테디셀러들도 어느 정도 포인트를 유지합니다. `SalesPoint`는 매일매일 업데이트됩니다. + more 9.2 100자평(123)리뷰(19)이 책 어때요?
# 전자책11,250원
#
#
#
#
# 종합 주간 7위,   종합 1위 3주|Sales Point : 288,115  세일즈 포인트 SalesPoint는 판매량과 판매기간에 근거하여 해당 상품의 판매도를 산출한 알라딘만의 판매지수법입니다.최근 판매분에 가중치를 준 판매점수. 팔릴수록 올라가고 덜 팔리면 내려갑니다. 그래서 최근 베스트셀러는 높은 점수이며, 꾸준히 팔리는 스테디셀러들도 어느 정도 포인트를 유지합니다. `SalesPoint`는 매일매일 업데이트됩니다. + more
# Sales Point : 288,115  세일즈 포인트 SalesPoint는 판매량과 판매기간에 근거하여 해당 상품의 판매도를 산출한 알라딘만의 판매지수법입니다.최근 판매분에 가중치를 준 판매점수. 팔릴수록 올라가고 덜 팔리면 내려갑니다. 그래서 최근 베스트셀러는 높은 점수이며, 꾸준히 팔리는 스테디셀러들도 어느 정도 포인트를 유지합니다. `SalesPoint`는 매일매일 업데이트됩니다. + more
#  세일즈 포인트 SalesPoint는 판매량과 판매기간에 근거하여 해당 상품의 판매도를 산출한 알라딘만의 판매지수법입니다.최근 판매분에 가중치를 준 판매점수. 팔릴수록 올라가고 덜 팔리면 내려갑니다. 그래서 최근 베스트셀러는 높은 점수이며, 꾸준히 팔리는 스테디셀러들도 어느 정도 포인트를 유지합니다. `SalesPoint`는 매일매일 업데이트됩니다. + more
#  세일즈 포인트 SalesPoint는 판매량과 판매기간에 근거하여 해당 상품의 판매도를 산출한 알라딘만의 판매지수법입니다.최근 판매분에 가중치를 준 판매점수. 팔릴수록 올라가고 덜 팔리면 내려갑니다. 그래서 최근 베스트셀러는 높은 점수이며, 꾸준히 팔리는 스테디셀러들도 어느 정도 포인트를 유지합니다. `SalesPoint`는 매일매일 업데이트됩니다. + more
#  세일즈 포인트 SalesPoint는 판매량과 판매기간에 근거하여 해당 상품의 판매도를 산출한 알라딘만의 판매지수법입니다.최근 판매분에 가중치를 준 판매점수. 팔릴수록 올라가고 덜 팔리면 내려갑니다. 그래서 최근 베스트셀러는 높은 점수이며, 꾸준히 팔리는 스테디셀러들도 어느 정도 포인트를 유지합니다. `SalesPoint`는 매일매일 업데이트됩니다. + more
#
#
# SalesPoint는 판매량과 판매기간에 근거하여 해당 상품의 판매도를 산출한 알라딘만의 판매지수법입니다.최근 판매분에 가중치를 준 판매점수. 팔릴수록 올라가고 덜 팔리면 내려갑니다. 그래서 최근 베스트셀러는 높은 점수이며, 꾸준히 팔리는 스테디셀러들도 어느 정도 포인트를 유지합니다. `SalesPoint`는 매일매일 업데이트됩니다. + more
# + more
#  9.2 100자평(123)리뷰(19)이 책 어때요?
#
# 이 책 어때요?
#
# 전자책11,250원
# 전자책
# 11,250원
#
#  카드/간편결제 할인 무이자 할부 소득공제 710원
#
#
#
#
#
#  무이자 할부 안내
#
#
#
#
#
#                 * 2~3개월 무이자 : 신한, 국민,현대,롯데,하나,삼성
# * 2~4개월 무이자 : 농협
# * 2~6개월 무이자 : 비씨, 우리
# ※ 제휴 신용카드 결제시 무이자+제휴카드 혜택 가능합니다.
# ※ 오프라인결제/Non ActiveX 결제(간편결제)/카카오페이/네이버페이/페이코 등 간편결제/법인/체크/선불/기프트/문화누리/은행계열카드/ 알라딘 캐시와 같은 정기과금 결제 등은 행사대상에서 제외됩니다.
# ※ 무이자할부 결제 시 카드사 포인트 적립에서 제외될 수 있습니다.
# ※ 본 행사는 카드사 사정에 따라 변경 또는 중단될 수 있습니다.
#
#
#
#
#
#
#  무이자 할부 안내
#
#
#
#
#
#                 * 2~3개월 무이자 : 신한, 국민,현대,롯데,하나,삼성
# * 2~4개월 무이자 : 농협
# * 2~6개월 무이자 : 비씨, 우리
# ※ 제휴 신용카드 결제시 무이자+제휴카드 혜택 가능합니다.
# ※ 오프라인결제/Non ActiveX 결제(간편결제)/카카오페이/네이버페이/페이코 등 간편결제/법인/체크/선불/기프트/문화누리/은행계열카드/ 알라딘 캐시와 같은 정기과금 결제 등은 행사대상에서 제외됩니다.
# ※ 무이자할부 결제 시 카드사 포인트 적립에서 제외될 수 있습니다.
# ※ 본 행사는 카드사 사정에 따라 변경 또는 중단될 수 있습니다.
#
#
#
#
#
#
#
#
#
#                 * 2~3개월 무이자 : 신한, 국민,현대,롯데,하나,삼성
# * 2~4개월 무이자 : 농협
# * 2~6개월 무이자 : 비씨, 우리
# ※ 제휴 신용카드 결제시 무이자+제휴카드 혜택 가능합니다.
# ※ 오프라인결제/Non ActiveX 결제(간편결제)/카카오페이/네이버페이/페이코 등 간편결제/법인/체크/선불/기프트/문화누리/은행계열카드/ 알라딘 캐시와 같은 정기과금 결제 등은 행사대상에서 제외됩니다.
# ※ 무이자할부 결제 시 카드사 포인트 적립에서 제외될 수 있습니다.
# ※ 본 행사는 카드사 사정에 따라 변경 또는 중단될 수 있습니다.
#
#
#
#
#
#
#
#
#
# 문과 남자의 과학 공부 - 나는 무엇이고 왜 존재하며 어디로 가는가?
#
# 15,750원 (10%, 1,750원 할인)
#
#
#
#
#
#
#
#
#
#
# 바로구매장바구니 담기
#
#
#
#
#
#
#
#
#
# 문과 남자의 과학 공부 - 나는 무엇이고 왜 존재하며 어디로 가는가?
#
# 15,750원 (10%, 1,750원 할인)
#
#
#
#
#
#
#
#
#
#
# 바로구매장바구니 담기
#
#
#
#
#
#
# 문과 남자의 과학 공부 - 나는 무엇이고 왜 존재하며 어디로 가는가?
#
# 15,750원 (10%, 1,750원 할인)
#
#
#
#
#
#
#
#
#
# 문과 남자의 과학 공부 - 나는 무엇이고 왜 존재하며 어디로 가는가?
#
# 15,750원 (10%, 1,750원 할인)
#
#
#
#
#
#
#
#
# 바로구매장바구니 담기
#
# 바로구매
# 장바구니 담기
#
#    수량
#
#
#
#
#
#
#
#
#
#
#
# 수량
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  상품을 장바구니에 담았습니다.
#
#
#
# 장바구니 가기
#
#
#
#
#
#
#
# x 닫기
#
# 상품을 장바구니에 담았습니다.
# 주문과정의 배송옵션에서 '영풍문고Now드림 방문 픽업' 을 선택해주세요.
#
# 장바구니 가기
#
#
#
#
#
#
#
#
#  상품을 장바구니에 담았습니다.
#
#
#
# 장바구니 가기
#
#
#
#
#
#
# 장바구니 가기
#
# 장바구니 가기
#
#
#
#
#
# x 닫기
#
# 상품을 장바구니에 담았습니다.
# 주문과정의 배송옵션에서 '영풍문고Now드림 방문 픽업' 을 선택해주세요.
#
# 장바구니 가기
#
#
#
#
#
#
#
#
#
# x 닫기
#
# 상품을 장바구니에 담았습니다.
# 주문과정의 배송옵션에서 '영풍문고Now드림 방문 픽업' 을 선택해주세요.
#
# 장바구니 가기
#
#
#
#
#
#
#
# x 닫기
#
# 상품을 장바구니에 담았습니다.
# 주문과정의 배송옵션에서 '영풍문고Now드림 방문 픽업' 을 선택해주세요.
#
# 장바구니 가기
#
#
#
# x 닫기
# 장바구니 가기
#
#
#
#
#
# 지금 바로 선물하기
#
# 장바구니 담기
#
# 장바구니에 담으면다른 상품과 함께 선물할 수 있어요.
#
#
#
#
#
# 지금 바로 선물하기
#
# 장바구니 담기
#
# 장바구니에 담으면다른 상품과 함께 선물할 수 있어요.
#
#
#
# 지금 바로 선물하기
# 지금 바로 선물하기
#
# 장바구니 담기
# 장바구니 담기
#
# 장바구니에 담으면다른 상품과 함께 선물할 수 있어요.
#
#
#
#  품절도서센터 장바구니에 담았습니다.
#
#
# 결제 후 신청이 완료됩니다.
#
#
# 품절도서 센터 장바구니
#
#
#
#
#
#  품절도서센터 장바구니에 담았습니다.
#
#
# 결제 후 신청이 완료됩니다.
#
#
# 품절도서 센터 장바구니
#
#
#
#
#
# 결제 후 신청이 완료됩니다.
#
#
# 품절도서 센터 장바구니
#
# 품절도서 센터 장바구니
#
#
#  보관함에 상품 담기
#
#
#
#
#
#
#  보관함에 상품 담기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 장바구니 담기
# 바로구매
#
#
#  선물하기  안내
#
#
# 배송 주소를 몰라도 선물할 수 있어요.
#
#
# 선물받으실 분의 핸드폰번호, 이메일 주소, 카카오톡 , 서재 주소 중 하나를 입력하시면 선물이 전송됩니다. + more
#
#
#
#
#
# 무엇을 선물할지 망설여진다면 알라딘 상품권을 선물해보세요.+ more
#
#
#
#
#
#
# 선물하기
#
#  선물하기  안내
#
#
# 배송 주소를 몰라도 선물할 수 있어요.
#
#
# 선물받으실 분의 핸드폰번호, 이메일 주소, 카카오톡 , 서재 주소 중 하나를 입력하시면 선물이 전송됩니다. + more
#
#
#
#
#
# 무엇을 선물할지 망설여진다면 알라딘 상품권을 선물해보세요.+ more
#
#
#
#
#
# 배송 주소를 몰라도 선물할 수 있어요.
#
#
# 선물받으실 분의 핸드폰번호, 이메일 주소, 카카오톡 , 서재 주소 중 하나를 입력하시면 선물이 전송됩니다. + more
#
#
# + more
#
#
#
# 무엇을 선물할지 망설여진다면 알라딘 상품권을 선물해보세요.+ more
#
#
# + more
#
#
#
#
#
#
# 보관함 +보관함마이리스트
# 보관함마이리스트
#
#
#
#
#  중고 등록알림 신청
#
#  중고로 팔기
#
#
#
#
# 알라딘에 팔기
#
#
# 회원에게 팔기
#
#
#
#
#
#
#
#
#
#
#
# 알라딘에 팔기
#
#
# 회원에게 팔기
#
#
#
#
#
#
# 알라딘에 팔기
#
#
# 회원에게 팔기
#
#
#
#
#
#
#
#
#  1:1 문의하기
#
#
# 분류 요청하기
# 품절/절판
# 출고 예상시간
# 가격 정보
# 상품상세정보
# 오탈자 신고
# 리뷰 신고
#
#
#
#
#
#
#
#
#  1:1 문의하기
#
#
# 분류 요청하기
# 품절/절판
# 출고 예상시간
# 가격 정보
# 상품상세정보
# 오탈자 신고
# 리뷰 신고
#
#
#
#
#
#  1:1 문의하기
#
#
# 분류 요청하기
# 품절/절판
# 출고 예상시간
# 가격 정보
# 상품상세정보
# 오탈자 신고
# 리뷰 신고
#
#
#
#
#
# 분류 요청하기
# 품절/절판
# 출고 예상시간
# 가격 정보
# 상품상세정보
# 오탈자 신고
# 리뷰 신고
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 기본정보
# 기본정보
#
#
# 304쪽135*210mm395gISBN : 9791192836188
#
#
#
# 주제 분류
# 신간알리미 신청
#
#
#
# 국내도서 > 인문학 > 교양 인문학 접기국내도서 > 과학 > 기초과학/교양과학 접기국내도서 > 인문학 > 인문 에세이 접기
#
#
#
#
#
#
#
#
#
#
#
#
#  무지를 드러내며 겸허하게 새로운 배움을 시작하는 태도, 새로운 앎을 받아들이는 과정, 배움을 통해 변하게 된 마음과 관점까지, 독자들이 자극받을 지점이 많은 책이다. 올여름휴가의 책으로 한자리는 이미 선점된 듯하다. - 인문 MD 김경영 (2023.06.23)
#
# 출판사 제공 북트레일러출판사 제공 북트레일러
#
#
#
#
#
#
#
#
#
#
#
#
#
# 이벤트
# 이벤트
#
#
#
#
#    <문과 남자의 과학 공부> 포함 국내도서 2만원 이상 구매 시, 유시민 사인 키보드 덮개     여름의 과학 + 책모양 거울(대상도서 포함 국내도서 2만원 이상 구매 시)     <문과 남자의 과학 공부> 구매 시, 오디오 매거진     이벤트 대상도서 1권이상 구매시 책꽂이 37호     이벤트 대상도서 포함 청소년 분야 2만원 이상 구매 시 단어장     책모양 유리문진(대상도서 포함 국내서 2만원 이상)     화제의 책+알라딘 굿즈 (이벤트 도서 포함, 국내도서 4만원 이상)     8월 특별 선물. 캠핑 의자 · 충전 패드 (이벤트 도서 포함, 국내서.외서 5만원 이상)
#      책과 함께 무료배송 - 함께 사기 좋은 특가 도서 · 저가 도서 총집합
#      이 달의 적립금 혜택     모든 책 오늘 출고 서비스 오픈     함께 사면 무료배송. 1천원~4천원대  굿즈 총집합     이 시간, 알라딘 사은품 총집합!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 기본정보
# 기본정보
#
#
# 304쪽135*210mm395gISBN : 9791192836188
#
#
#
# 주제 분류
# 신간알리미 신청
#
#
#
# 국내도서 > 인문학 > 교양 인문학 접기국내도서 > 과학 > 기초과학/교양과학 접기국내도서 > 인문학 > 인문 에세이 접기
#
#
#
#
#
#
# 기본정보
# 기본정보
#
#
# 304쪽135*210mm395gISBN : 9791192836188
#
#
#
# 주제 분류
# 신간알리미 신청
#
#
#
# 국내도서 > 인문학 > 교양 인문학 접기국내도서 > 과학 > 기초과학/교양과학 접기국내도서 > 인문학 > 인문 에세이 접기
#
#
#
#
# 304쪽135*210mm395gISBN : 9791192836188
#
#
# 주제 분류
# 신간알리미 신청
#
# 신간알리미 신청
#
#
# 국내도서 > 인문학 > 교양 인문학 접기국내도서 > 과학 > 기초과학/교양과학 접기국내도서 > 인문학 > 인문 에세이 접기
#
#
#
#
#  무지를 드러내며 겸허하게 새로운 배움을 시작하는 태도, 새로운 앎을 받아들이는 과정, 배움을 통해 변하게 된 마음과 관점까지, 독자들이 자극받을 지점이 많은 책이다. 올여름휴가의 책으로 한자리는 이미 선점된 듯하다. - 인문 MD 김경영 (2023.06.23)
# 편집장의 선택
# 편집장의 선택
#  무지를 드러내며 겸허하게 새로운 배움을 시작하는 태도, 새로운 앎을 받아들이는 과정, 배움을 통해 변하게 된 마음과 관점까지, 독자들이 자극받을 지점이 많은 책이다. 올여름휴가의 책으로 한자리는 이미 선점된 듯하다. - 인문 MD 김경영 (2023.06.23)
# "유시민이 과학책을 통해 얻은 것들"
#
# - 인문 MD 김경영 (2023.06.23)
#
#
# 출판사 제공 북트레일러출판사 제공 북트레일러
#
# 출판사 제공 북트레일러
# 출판사 제공 북트레일러
#
#
#
#
#
#
#
# 이벤트
# 이벤트
#
#
#
#
#    <문과 남자의 과학 공부> 포함 국내도서 2만원 이상 구매 시, 유시민 사인 키보드 덮개     여름의 과학 + 책모양 거울(대상도서 포함 국내도서 2만원 이상 구매 시)     <문과 남자의 과학 공부> 구매 시, 오디오 매거진     이벤트 대상도서 1권이상 구매시 책꽂이 37호     이벤트 대상도서 포함 청소년 분야 2만원 이상 구매 시 단어장     책모양 유리문진(대상도서 포함 국내서 2만원 이상)     화제의 책+알라딘 굿즈 (이벤트 도서 포함, 국내도서 4만원 이상)     8월 특별 선물. 캠핑 의자 · 충전 패드 (이벤트 도서 포함, 국내서.외서 5만원 이상)
#      책과 함께 무료배송 - 함께 사기 좋은 특가 도서 · 저가 도서 총집합
#      이 달의 적립금 혜택     모든 책 오늘 출고 서비스 오픈     함께 사면 무료배송. 1천원~4천원대  굿즈 총집합     이 시간, 알라딘 사은품 총집합!
#
#
#
#
#
#
#
#
#
#
# 이벤트
# 이벤트
#
#
#
#
#    <문과 남자의 과학 공부> 포함 국내도서 2만원 이상 구매 시, 유시민 사인 키보드 덮개     여름의 과학 + 책모양 거울(대상도서 포함 국내도서 2만원 이상 구매 시)     <문과 남자의 과학 공부> 구매 시, 오디오 매거진     이벤트 대상도서 1권이상 구매시 책꽂이 37호     이벤트 대상도서 포함 청소년 분야 2만원 이상 구매 시 단어장     책모양 유리문진(대상도서 포함 국내서 2만원 이상)     화제의 책+알라딘 굿즈 (이벤트 도서 포함, 국내도서 4만원 이상)     8월 특별 선물. 캠핑 의자 · 충전 패드 (이벤트 도서 포함, 국내서.외서 5만원 이상)
#      책과 함께 무료배송 - 함께 사기 좋은 특가 도서 · 저가 도서 총집합
#      이 달의 적립금 혜택     모든 책 오늘 출고 서비스 오픈     함께 사면 무료배송. 1천원~4천원대  굿즈 총집합     이 시간, 알라딘 사은품 총집합!
#
#
#
#
#
#
#
#
#
#
#    <문과 남자의 과학 공부> 포함 국내도서 2만원 이상 구매 시, 유시민 사인 키보드 덮개     여름의 과학 + 책모양 거울(대상도서 포함 국내도서 2만원 이상 구매 시)     <문과 남자의 과학 공부> 구매 시, 오디오 매거진     이벤트 대상도서 1권이상 구매시 책꽂이 37호     이벤트 대상도서 포함 청소년 분야 2만원 이상 구매 시 단어장     책모양 유리문진(대상도서 포함 국내서 2만원 이상)     화제의 책+알라딘 굿즈 (이벤트 도서 포함, 국내도서 4만원 이상)     8월 특별 선물. 캠핑 의자 · 충전 패드 (이벤트 도서 포함, 국내서.외서 5만원 이상)
#      책과 함께 무료배송 - 함께 사기 좋은 특가 도서 · 저가 도서 총집합
#      이 달의 적립금 혜택     모든 책 오늘 출고 서비스 오픈     함께 사면 무료배송. 1천원~4천원대  굿즈 총집합     이 시간, 알라딘 사은품 총집합!
#
#
#
#    <문과 남자의 과학 공부> 포함 국내도서 2만원 이상 구매 시, 유시민 사인 키보드 덮개     여름의 과학 + 책모양 거울(대상도서 포함 국내도서 2만원 이상 구매 시)     <문과 남자의 과학 공부> 구매 시, 오디오 매거진     이벤트 대상도서 1권이상 구매시 책꽂이 37호     이벤트 대상도서 포함 청소년 분야 2만원 이상 구매 시 단어장     책모양 유리문진(대상도서 포함 국내서 2만원 이상)     화제의 책+알라딘 굿즈 (이벤트 도서 포함, 국내도서 4만원 이상)     8월 특별 선물. 캠핑 의자 · 충전 패드 (이벤트 도서 포함, 국내서.외서 5만원 이상)
#      책과 함께 무료배송 - 함께 사기 좋은 특가 도서 · 저가 도서 총집합
#      이 달의 적립금 혜택     모든 책 오늘 출고 서비스 오픈     함께 사면 무료배송. 1천원~4천원대  굿즈 총집합     이 시간, 알라딘 사은품 총집합!
#
# <문과 남자의 과학 공부> 포함 국내도서 2만원 이상 구매 시, 유시민 사인 키보드 덮개
# 여름의 과학 + 책모양 거울(대상도서 포함 국내도서 2만원 이상 구매 시)
# <문과 남자의 과학 공부> 구매 시, 오디오 매거진
# 이벤트 대상도서 1권이상 구매시 책꽂이 37호
# 이벤트 대상도서 포함 청소년 분야 2만원 이상 구매 시 단어장
# 책모양 유리문진(대상도서 포함 국내서 2만원 이상)
# 화제의 책+알라딘 굿즈 (이벤트 도서 포함, 국내도서 4만원 이상)
# 8월 특별 선물. 캠핑 의자 · 충전 패드 (이벤트 도서 포함, 국내서.외서 5만원 이상)
#
# 책과 함께 무료배송 - 함께 사기 좋은 특가 도서 · 저가 도서 총집합
#
# 이 달의 적립금 혜택
# 모든 책 오늘 출고 서비스 오픈
# 함께 사면 무료배송. 1천원~4천원대  굿즈 총집합
# 이 시간, 알라딘 사은품 총집합!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 회사소개
# 채용안내
# 이용약관
# 개인정보처리방침
# 청소년 보호정책
# 중고매장
# 제휴·마케팅 안내
# 판매자 매니저
# 출판사·공급사 안내
# 광고 안내
# 학교·기업·기관 대량구매
#
#
#
#
# (주)알라딘커뮤니케이션
#
# 대표이사 최우경
# 고객정보보호 책임자 최우경
# 사업자등록 201-81-23094
# 통신판매업신고 중구01520호
# 이메일 privacy@aladin.co.kr
# 호스팅 제공자 알라딘커뮤니케이션
# (본사) 서울시 중구 서소문로 89-31
# ⓒ Aladin Communication. All Rights Reserved.
#
#
# 구매안전 에스크로서비스 가입 확인
# 정보보호 관리체계ISMS 인증획득
#
#
#
# 고객센터 1544-2514 (발신자 부담)
#
# 서울시 마포구 백범로 71 숨도빌딩 7층
# Fax 02-6926-2600
#
#
# 1:1 문의
# FAQ
#
#
# 중고매장 위치, 영업시간 안내
#
#
#
#
#
#
# 회사소개
# 채용안내
# 이용약관
# 개인정보처리방침
# 청소년 보호정책
# 중고매장
# 제휴·마케팅 안내
# 판매자 매니저
# 출판사·공급사 안내
# 광고 안내
# 학교·기업·기관 대량구매
#
#
#
#
# (주)알라딘커뮤니케이션
#
# 대표이사 최우경
# 고객정보보호 책임자 최우경
# 사업자등록 201-81-23094
# 통신판매업신고 중구01520호
# 이메일 privacy@aladin.co.kr
# 호스팅 제공자 알라딘커뮤니케이션
# (본사) 서울시 중구 서소문로 89-31
# ⓒ Aladin Communication. All Rights Reserved.
#
#
# 구매안전 에스크로서비스 가입 확인
# 정보보호 관리체계ISMS 인증획득
#
#
#
# 고객센터 1544-2514 (발신자 부담)
#
# 서울시 마포구 백범로 71 숨도빌딩 7층
# Fax 02-6926-2600
#
#
# 1:1 문의
# FAQ
#
#
# 중고매장 위치, 영업시간 안내
#
#
#
#
# (주)알라딘커뮤니케이션
#
# 대표이사 최우경
# 고객정보보호 책임자 최우경
# 사업자등록 201-81-23094
# 통신판매업신고 중구01520호
# 이메일 privacy@aladin.co.kr
# 호스팅 제공자 알라딘커뮤니케이션
# (본사) 서울시 중구 서소문로 89-31
# ⓒ Aladin Communication. All Rights Reserved.
#
#
# 구매안전 에스크로서비스 가입 확인
# 정보보호 관리체계ISMS 인증획득
#
#
# ⓒ Aladin Communication. All Rights Reserved.
#
# 구매안전 에스크로서비스 가입 확인
# 정보보호 관리체계ISMS 인증획득
#
#
# 고객센터 1544-2514 (발신자 부담)
#
# 서울시 마포구 백범로 71 숨도빌딩 7층
# Fax 02-6926-2600
#
#
# 1:1 문의
# FAQ
#
#
# 중고매장 위치, 영업시간 안내
#
#
#
# 1:1 문의
# FAQ
#
#
# 중고매장 위치, 영업시간 안내

# %%
# 셜록 홈즈 전집 (9권)

import requests
from bs4 import BeautifulSoup
import pandas as pd

# 크롤링 함수 정의
def crawl_aladin(item_id):
    url = f"https://www.aladin.co.kr/shop/wproduct.aspx?ItemId={item_id}"

    response = requests.get(url)
    soup = BeautifulSoup(response.content, "html.parser")

    # 제목 (Title)
    title = soup.find("span", class_="Ere_bo_title").text.strip()

    # 저자 (Author)
    author = soup.find("a", class_="Ere_sub2_title").text.strip()

    # 책소개 (book_intro)
    #book_intro_div = soup.find('div', class_='Ere_prod_mconts_R')
    #book_intro = book_intro_div.get_text(strip=True)

    '''
    # 목차 (Content)
    content_a = soup.find("a", href="javascript:fn_hide_introduce_TOC('TOC')")
    content_p = content_a.find("p") if content_a else None
    table_of_contents = content_p.text.strip() if content_p else None


    # 책속에서 (From the Book)
    book_content_span = soup.select_one("#u3_1")
    if book_content_span:
        book_content_text = book_content_span.text.split("더보기")[0].strip()
    else:
        book_content_text = None

    '''

    # 구매 링크 (Buy Link)
    buylink = url  # 제공된 URL로 직접 재정의

    # 가격 (Price)
    price = soup.find('span', class_='Ere_fs24').text.strip()

    # 장르
    genre_list = []
    ul_genre = soup.find('ul', id='ulCategory')
    for li in ul_genre.find_all('li'):
        genre_path = [a.text for a in li.find_all('a') if "CID" in a['href']]
        genre_list.append(" > ".join(genre_path))
    genres = ", ".join(genre_list)

    # 결과 반환
    return {
        "제목": title,
        "저자": author,
        #"책소개": book_intro,
        #"책속에서": book_content_text,
        #"목차": table_of_contents,
        "구매 링크": buylink,
        "가격": price,
        "장르": genres
    }


# 아이템 ID 목록
item_ids = [
    "329982", # 1
    "329984", # 2
    "329985", # 3
    "329986", # 4
    "343427", # 5
    "348231", # 6
    "365283", # 7
    "374820", # 8
    "383268", # 전9원

    # 381882 # 9
]


'''
# 아이템 test ID 목록
item_ids = [
    "381882" # 9
]
'''

# 각 아이템 ID에 대해 크롤링 수행
results = [crawl_aladin(item_id) for item_id in item_ids]

# 데이터프레임 생성
df = pd.DataFrame(results)
display(df)
print()

# 저장할 파일명 지정
filename = "셜록호즈_data.csv"

# 지정된 경로에 파일 저장
path = f"/content/drive/MyDrive/ChatGpt 프로젝트/코딩/kogpt2/Crawling Data/{filename}"
df.to_csv(path, index=False)

print(f"'{filename}' 파일이 성공적으로 저장되었습니다.")
# Out:
#                           제목        저자  \
# 0            셜록 홈즈 전집 1 (양장)  아서 코난 도일
# 1            셜록 홈즈 전집 2 (양장)  아서 코난 도일
# 2            셜록 홈즈 전집 3 (양장)  아서 코난 도일
# 3            셜록 홈즈 전집 4 (양장)  아서 코난 도일
# 4            셜록 홈즈 전집 5 (양장)  아서 코난 도일
# 5            셜록 홈즈 전집 6 (양장)  아서 코난 도일
# 6            셜록 홈즈 전집 7 (양장)  아서 코난 도일
# 7            셜록 홈즈 전집 8 (양장)  아서 코난 도일
# 8  셜록 홈즈 전집 양장 세트 - 전9권 (2판)  아서 코난 도일
#
#                                                구매 링크      가격  \
# 0  https://www.aladin.co.kr/shop/wproduct.aspx?It...   7,920
# 1  https://www.aladin.co.kr/shop/wproduct.aspx?It...   9,000
# 2  https://www.aladin.co.kr/shop/wproduct.aspx?It...   9,900
# 3  https://www.aladin.co.kr/shop/wproduct.aspx?It...   9,900
# 4  https://www.aladin.co.kr/shop/wproduct.aspx?It...  11,700
# 5  https://www.aladin.co.kr/shop/wproduct.aspx?It...  10,800
# 6  https://www.aladin.co.kr/shop/wproduct.aspx?It...  10,800
# 7  https://www.aladin.co.kr/shop/wproduct.aspx?It...   8,100
# 8  https://www.aladin.co.kr/shop/wproduct.aspx?It...  54,000
#
#                                                   장르
# 0  소설/시/희곡 > 추리/미스터리소설 > 영미 추리/미스터리소설, 소설/시/희곡 > ...
# 1  소설/시/희곡 > 추리/미스터리소설 > 영미 추리/미스터리소설, 소설/시/희곡 > ...
# 2  소설/시/희곡 > 추리/미스터리소설 > 영미 추리/미스터리소설, 소설/시/희곡 > ...
# 3  소설/시/희곡 > 추리/미스터리소설 > 영미 추리/미스터리소설, 소설/시/희곡 > ...
# 4  소설/시/희곡 > 추리/미스터리소설 > 영미 추리/미스터리소설, 소설/시/희곡 > ...
# 5  소설/시/희곡 > 추리/미스터리소설 > 영미 추리/미스터리소설, 소설/시/희곡 > ...
# 6  소설/시/희곡 > 추리/미스터리소설 > 영미 추리/미스터리소설, 소설/시/희곡 > ...
# 7  소설/시/희곡 > 추리/미스터리소설 > 영미 추리/미스터리소설, 소설/시/희곡 > ...
# 8  소설/시/희곡 > 추리/미스터리소설 > 영미 추리/미스터리소설, 소설/시/희곡 > ...
# '셜록호즈_data.csv' 파일이 성공적으로 저장되었습니다.

# %%
# 베스트 셀러


import requests
from bs4 import BeautifulSoup
import pandas as pd

# 크롤링 함수 정의
def crawl_aladin(item_id):
    url = f"https://www.aladin.co.kr/shop/wproduct.aspx?ItemId={item_id}"

    response = requests.get(url)
    soup = BeautifulSoup(response.content, "html.parser")

    # 제목 (Title)
    title = soup.find("span", class_="Ere_bo_title").text.strip()

    # 저자 (Author)
    author = soup.find("a", class_="Ere_sub2_title").text.strip()

    # 책소개 (book_intro)
    #book_intro_div = soup.find('div', class_='Ere_prod_mconts_R')
    #book_intro = book_intro_div.get_text(strip=True)

    '''
    # 목차 (Content)
    content_a = soup.find("a", href="javascript:fn_hide_introduce_TOC('TOC')")
    content_p = content_a.find("p") if content_a else None
    table_of_contents = content_p.text.strip() if content_p else None


    # 책속에서 (From the Book)
    book_content_span = soup.select_one("#u3_1")
    if book_content_span:
        book_content_text = book_content_span.text.split("더보기")[0].strip()
    else:
        book_content_text = None

    '''

    # 구매 링크 (Buy Link)
    buylink = url  # 제공된 URL로 직접 재정의

    # 가격 (Price)
    price = soup.find('span', class_='Ere_fs24').text.strip()

    # 장르
    genre_list = []
    ul_genre = soup.find('ul', id='ulCategory')
    for li in ul_genre.find_all('li'):
        genre_path = [a.text for a in li.find_all('a') if "CID" in a['href']]
        genre_list.append(" > ".join(genre_path))
    genres = ", ".join(genre_list)

    # 결과 반환
    return {
        "제목": title,
        "저자": author,
        #"책소개": book_intro,
        #"책속에서": book_content_text,
        #"목차": table_of_contents,
        "구매 링크": buylink,
        "가격": price,
        "장르": genres
    }
329982 # 1
329984 # 2
329985 # 3
329986 # 4
343427 # 5
348231 # 6
365283 # 7
374820 # 8
383268 # 전9원

# 381882 # 9

# 아이템 ID 목록
item_ids = [
    "318773745",
    "323272146",
    "321294005",
    "315599742",
    "315599742",
    "323084340",
    "322806235",
    "317300995",
    "318885306",
    "318677116"
]

# 각 아이템 ID에 대해 크롤링 수행
results = [crawl_aladin(item_id) for item_id in item_ids]

# 데이터프레임 생성
df = pd.DataFrame(results)
display(df)
print()

# 저장할 파일명 지정
filename = "aladin_books_data.csv"

# 지정된 경로에 파일 저장
path = f"/content/drive/MyDrive/ChatGpt 프로젝트/코딩/kogpt2/Crawling Data/{filename}"
df.to_csv(path, index=False)

print(f"'{filename}' 파일이 성공적으로 저장되었습니다.")
# Out:
#                 제목        저자  \
# 0     문과 남자의 과학 공부       유시민
# 1     안녕, 에리 (한정판)  후지모토 타츠키
# 2      아주 희미한 빛으로도       최은영
# 3         도둑맞은 집중력     요한 하리
# 4         도둑맞은 집중력     요한 하리
# 5             슈퍼노멀       주언규
# 6  별의 커비 푸푸푸 히어로 1    아오키 케이
# 7          역행자 확장판        자청
# 8         최소한의 한국사       최태성
# 9     비가 오면 열리는 상점       유영광
#
#                                                구매 링크      가격  \
# 0  https://www.aladin.co.kr/shop/wproduct.aspx?It...  15,750
# 1  https://www.aladin.co.kr/shop/wproduct.aspx?It...  16,200
# 2  https://www.aladin.co.kr/shop/wproduct.aspx?It...  15,120
# 3  https://www.aladin.co.kr/shop/wproduct.aspx?It...  16,920
# 4  https://www.aladin.co.kr/shop/wproduct.aspx?It...  16,920
# 5  https://www.aladin.co.kr/shop/wproduct.aspx?It...  17,550
# 6  https://www.aladin.co.kr/shop/wproduct.aspx?It...   9,900
# 7  https://www.aladin.co.kr/shop/wproduct.aspx?It...  17,550
# 8  https://www.aladin.co.kr/shop/wproduct.aspx?It...  16,200
# 9  https://www.aladin.co.kr/shop/wproduct.aspx?It...  15,120
#
#                                                   장르
# 0         인문학 > 교양 인문학, 과학 > 기초과학/교양과학, 인문학 > 인문 에세이
# 1                                      만화 > 논픽션/휴먼만화
# 2                    소설/시/희곡 > 한국소설 > 2000년대 이후 한국소설
# 3      인문학 > 심리학/정신분석학 > 교양 심리학, 사회과학 > 사회학 > 사회학 일반
# 4      인문학 > 심리학/정신분석학 > 교양 심리학, 사회과학 > 사회학 > 사회학 일반
# 5                                    자기계발 > 성공 > 성공학
# 6          어린이 > 게임 만화/캐릭터도감, 어린이 > TV/만화/영화 > 만화 일반
# 7  자기계발 > 성공 > 성공학, 경제경영 > CEO/비즈니스맨을 위한 능력계발 > 성...
# 8                                        역사 > 한국사 일반
# 9  소설/시/희곡 > 판타지/환상문학 > 한국판타지/환상소설, 소설/시/희곡 > 한국소...
# 'aladin_books_data.csv' 파일이 성공적으로 저장되었습니다.
